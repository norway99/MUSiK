# %%
import sys
import os

parent = os.path.dirname(os.path.realpath("../"))
sys.path.append(parent)

import numpy as np
import scipy
import tqdm
import matplotlib.pyplot as plt
import glob


from musik import *
from utils import geometry

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import open3d as o3d
from utils import phantom_builder
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# # Make Phantom

# %%
voxel_size = np.array([0.001, 0.001, 0.001])
# voxel_size = np.array([0.0005, 0.0005, 0.0005])
surface_mesh = o3d.io.read_triangle_mesh(
    f"{parent}/assets/cardiac_TEE_phantom/esophageal_surface.ply"
)
body_mask = phantom_builder.voxelize(voxel_size[0], mesh=surface_mesh)

# %%
test_phantom = phantom.Phantom(
    voxel_dims=(voxel_size[0], voxel_size[0], voxel_size[0]),
    matrix_dims=body_mask.shape,
    baseline=(1540, 1000),
    seed=None,
)

blood = tissue.Tissue(name="blood", c=1578, rho=1060, sigma=1.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(
    name="myocardium", c=1592, rho=1081, sigma=20, scale=0.0001, label=2
)
esophagus = tissue.Tissue(
    name="esophagus", c=1500, rho=1100, sigma=10, scale=0.0001, label=3
)
fat = tissue.Tissue(name="fat", c=1480, rho=970, sigma=15, scale=0.0001, label=4)

heart_file_dir = f"{parent}/assets/cardiac_TEE_phantom"

heart_tissue_list = [blood, myocardium, esophagus]

test_phantom.build_organ_from_mesh(
    surface_mesh, voxel_size[0], heart_tissue_list, dir_path=heart_file_dir
)
test_phantom.set_default_tissue(fat)
# Out:
# Added blood
# Added myocardium
# Added esophagus

# %%
test = test_phantom.get_complete()

# %%
test.shape
# Out:
# (2, 206, 225, 300)

# %%
index = 150
plt.imshow(test[0, :, :, index], cmap="gray", vmin=1450, vmax=1650)
plt.imshow(
    body_mask[:, :, index], alpha=(body_mask[:, :, index] > 0) * 0.9, cmap="Reds"
)

# %% [markdown]
# # Set up simulation

# %% [markdown]
# ### Test

# %%
num_transducers = 8
transducers = [
    transducer.Focused(
        max_frequency=1.0e6,   # changed, 0.8e6
        elements=128,
        width=20e-3,
        height=20e-3,
        sensor_sampling_scheme="not_centroid",
        sweep=np.pi / 2,    # np.pi / 2,
        ray_num=32,    # changed, 64
        imaging_ndims=2,
        focus_azimuth=100e-3,
        focus_elevation=150e-3,
        cycles=3,
    )
    for i in range(num_transducers)
]


for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

test_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)

# %%
# get random position
def rand_position_box(xmin, xmax, ymin, ymax, zmin, zmax):
    x = np.random.uniform(xmin, xmax)
    y = np.random.uniform(ymin, ymax)
    z = np.random.uniform(zmin, zmax)
    return [x, y, z]

def rand_position_polar_uniform(rmin, rmax, pitch_min, pitch_max, yaw_min, yaw_max):
    """Spatially uniform sampling within a spherical sector."""
    # Uniform in r³ for radial uniformity
    r = (np.random.uniform(rmin**3, rmax**3)) ** (1/3)
    
    # Uniform in sin(pitch) for angular uniformity
    sin_pitch = np.random.uniform(np.sin(pitch_min), np.sin(pitch_max))
    pitch = np.arcsin(sin_pitch)
    
    yaw = np.random.uniform(yaw_min, yaw_max)
    
    x = r * np.cos(pitch) * np.cos(yaw)
    y = r * np.cos(pitch) * np.sin(yaw)
    z = r * np.sin(pitch)
    
    return [x, y, z]

# %%
# ## correct version
# def euler_face_origin_xyz(position):
#     """
#     Return [rx, ry, rz] (radians) so a +Z-forward transducer at `position`
#     faces the origin (0,0,0) in a Y-up world. Roll is set to 0.
#     """
#     x, y, z = position
#     # Vector from transducer -> origin
#     dx, dy, dz = -x, -y, -z

#     # Yaw (about Y): turn in XZ plane toward the origin
#     yaw = np.arctan2(dx, dz)               # ry
#     # Apply additional downward yaw of 90° (π/2 radians)
#     yaw -= np.pi / 2
#     # Pitch (about X): tilt up/down toward the origin
#     horiz = np.hypot(dx, dz)
#     pitch = - np.arctan2(dy, horiz)          # rx


#     # Roll (about Z): keep upright
#     roll = 0                      # rz
#     return [pitch, yaw, roll]


# Correct for now --> get back to fix yaw, pitch, roll
def euler_face_origin_xyz(position):
    """
    Return [rx, ry, rz] (radians) so a +Z-forward transducer at `position`
    faces the origin (0,0,0) in a right-handed world with:
      - roll (x-axis)
      - pitch (y-axis)
      - yaw (z-axis)
    """
    x, y, z = position
    dx, dy, dz = -x, -y, -z  # vector to origin

    # --- Yaw (about Z): rotate in XY plane toward origin ---
    yaw = np.arctan2(dy, dx)  # rz

    # --- Pitch (about Y): tilt up/down toward origin ---
    horiz = np.hypot(dx, dy)
    pitch = np.arctan2(dz, horiz)  # ry

    # --- Roll (about X): keep upright ---
    roll = 0  # rx

    return [yaw, -pitch, roll]

# %%
def add_random_rotation_noise(euler, roll_noise_deg=180, yaw_noise_deg=25, pitch_noise_deg=25):

    yaw, pitch, roll = euler

    # Roll noise uniformly from -180° to +180°
    r_noise_deg = np.random.uniform(-roll_noise_deg, roll_noise_deg)
    r_noise_rad = np.deg2rad(r_noise_deg)
    roll_noisy = roll + r_noise_rad

    # Yaw noise uniformly from -25° to +25°
    y_noise_deg = np.random.uniform(-yaw_noise_deg, yaw_noise_deg)
    y_noise_rad = np.deg2rad(y_noise_deg)
    yaw_noisy = yaw + y_noise_rad

    # Pitch noise uniformly from -25° to +25°
    p_noise_deg = np.random.uniform(-pitch_noise_deg, pitch_noise_deg)
    p_noise_rad = np.deg2rad(p_noise_deg)
    pitch_noisy = pitch + p_noise_rad

    return [yaw_noisy, pitch_noisy, roll_noisy]

# %%
def make_transform_facing_origin(position):
    euler = euler_face_origin_xyz(position)
    T = geometry.Transform(euler, position)
    # euler_noisy = add_random_rotation_noise(euler)
    # T = geometry.Transform(euler, position)
    # T = geometry.Transform(euler_noisy, position)

    T.translation = np.array(position, dtype=float)
    return T

# %%
positions = []
for i in range(num_transducers):
    pos = rand_position_polar_uniform(0.11, 0.12, -0.05, -0.05, -2, 2)
    positions.append(pos)

    transform = make_transform_facing_origin(pos)
    test_transducer_set.assign_pose(i, transform)

pos_arr = np.asarray(positions, dtype=float)   # shape: (N,3)

# %%
# test plot
# points = np.array((o3d.io.read_triangle_mesh(f"{parent}/assets/cardiac_TEE_phantom/02_myocardium.obj")).sample_points_uniformly(5000).points)
points = np.array(
    (o3d.io.read_triangle_mesh(f"/{parent}/assets/cardiac_TEE_phantom/01_bloodpool.obj"))
    .sample_points_uniformly(8000)
    .points
)

test_transducer_set.plot_transducer_coords(
    scale=0.15, phantom_coords=points, view=(90, 0)
)
# test_transducer_set.plot_transducer_coords(
#     scale=0.15, phantom_coords=points, view=(0, 0)
# )
# test_transducer_set.plot_transducer_coords(
#     scale=0.15, phantom_coords=points, view=(0, 90)
# )

# %%
test_transducer_set.plot_transducer_fovs(scale = 0.1, view=(90, 0))
# test_transducer_set.plot_transducer_fovs(scale = 0.1, view=(0, 0))
# test_transducer_set.plot_transducer_fovs(scale = 0.1, view=(0, 90))

# %% [markdown]
# ### Original Code

# %%
test_sensor = sensor.Sensor(
    transducer_set=test_transducer_set, aperture_type="transmit_as_receive"
)

# %%
simprops = simulation.SimProperties(
    grid_size=(200e-3, 25e-3, 25e-3),
    voxel_size=(0.5e-3, 0.5e-3, 0.5e-3),
    PML_size=(16, 16, 16),
    PML_alpha=2,
    t_end=12e-5,  # [s]
    bona=6,  # parameter b/a determining degree of nonlinear acoustic effects
    alpha_coeff=0.5,  # [dB/(MHz^y cm)]
    alpha_power=1.5,
)

# %%
test_experiment = experiment.Experiment(
    simulation_path=f"TTE_planar",
    sim_properties=simprops,
    phantom=test_phantom,
    transducer_set=test_transducer_set,
    sensor=test_sensor,
    nodes=1,
    results=None,
    indices=None,
    workers=4,
    additional_keys=[],
)

test_experiment.save()
# Out:
# workers is the number of simulations being prepared simultaneously on a single gpu node. Having many workers is RAM intensive and may not decrease overall runtime

# %% [markdown]
# # Run Simulation

# %%
test_experiment = experiment.Experiment.load(f"TTE_planar")
test_experiment.run(dry=True)
# Out:
# Number of simulation results (0) is less than the expected number of simulation results (256), are you sure the simulation finished running?
# dry run of simulation
# 100%|██████████| 8/8 [00:02<00:00,  2.83it/s]

# %%
test_experiment.plot_ray_path(32*1+16)
test_experiment.plot_ray_path(32*2+16)

# %%
test_experiment.run(repeat=False)
# Out:
# running with 4 workers
#
# preparation for sim    0 completed in  9.89 seconds
# preparation for sim    1 completed in 12.99 seconds
# preparation for sim   86 completed in 12.99 seconds
# preparation for sim  171 completed in 14.68 seconds
# preparation for sim    2 completed in 12.87 seconds
# preparation for sim   87 completed in 12.19 seconds
# simulation             0 completed in 24.41 seconds
# simulation            86 completed in 20.77 seconds
# simulation             1 completed in 20.89 seconds
# preparation for sim  172 completed in 13.49 seconds
# preparation for sim   88 completed in 13.10 seconds
# preparation for sim    3 completed in 14.73 seconds
# simulation           171 completed in 31.86 seconds
# simulation            87 completed in 20.91 seconds
# simulation             2 completed in 20.96 seconds
# preparation for sim    4 completed in 11.23 seconds
# preparation for sim   89 completed in 11.46 seconds
# preparation for sim  173 completed in 11.60 seconds
# simulation           172 completed in 26.81 seconds
# simulation            88 completed in 21.05 seconds
# simulation             3 completed in 21.14 seconds
# preparation for sim    5 completed in 11.27 seconds
# preparation for sim   90 completed in 10.68 seconds
# preparation for sim  174 completed in 11.14 seconds
# simulation           173 completed in 26.57 seconds
# simulation            89 completed in 21.07 seconds
# simulation             4 completed in 21.13 seconds
# preparation for sim    6 completed in 11.37 seconds
# preparation for sim   91 completed in 10.44 seconds
# preparation for sim  175 completed in 11.05 seconds
# simulation           174 completed in 24.16 seconds
# simulation            90 completed in 21.12 seconds
# simulation             5 completed in 21.20 seconds
# preparation for sim  176 completed in 13.05 seconds
# preparation for sim    7 completed in 14.75 seconds
# preparation for sim   92 completed in 14.10 seconds
# simulation           175 completed in 32.07 seconds
# simulation            91 completed in 21.20 seconds
# simulation             6 completed in 21.04 seconds
# preparation for sim    8 completed in 13.05 seconds
# preparation for sim   93 completed in 12.82 seconds
# preparation for sim  177 completed in 13.02 seconds
# simulation           176 completed in 31.66 seconds
# simulation            92 completed in 21.11 seconds
# simulation             7 completed in 21.14 seconds
# preparation for sim    9 completed in 10.65 seconds
# preparation for sim   94 completed in 10.63 seconds
# preparation for sim  178 completed in 11.92 seconds
# simulation           177 completed in 23.04 seconds
# simulation            93 completed in 21.21 seconds
# simulation             8 completed in 21.48 seconds
# preparation for sim   10 completed in 13.43 seconds
# preparation for sim   95 completed in 13.27 seconds
# preparation for sim  179 completed in 14.81 seconds
# simulation           178 completed in 32.62 seconds
# simulation            94 completed in 21.08 seconds
# simulation             9 completed in 21.51 seconds
# preparation for sim  180 completed in 13.51 seconds
# preparation for sim   96 completed in 12.23 seconds
# preparation for sim   11 completed in 12.35 seconds
# simulation           179 completed in 31.10 seconds
# simulation            95 completed in 21.07 seconds
# simulation            10 completed in 21.13 seconds
# preparation for sim  181 completed in 11.66 seconds
# preparation for sim   97 completed in 11.82 seconds
# preparation for sim   12 completed in 12.04 seconds
# simulation           180 completed in 23.59 seconds
# simulation            96 completed in 21.18 seconds
# simulation            11 completed in 21.28 seconds
# preparation for sim  182 completed in 13.32 seconds
# preparation for sim   98 completed in 12.74 seconds
# preparation for sim   13 completed in 13.59 seconds
# simulation           181 completed in 31.67 seconds
# simulation            97 completed in 21.15 seconds
# simulation            12 completed in 21.16 seconds
# preparation for sim  183 completed in 10.82 seconds
# preparation for sim   99 completed in 10.64 seconds
# preparation for sim   14 completed in 10.45 seconds
# simulation           182 completed in 21.73 seconds
# simulation            98 completed in 21.28 seconds
# simulation            13 completed in 21.27 seconds
# preparation for sim  100 completed in 11.59 seconds
# preparation for sim  184 completed in 11.79 seconds
# preparation for sim   15 completed in 12.23 seconds
# simulation           183 completed in 28.96 seconds
# simulation            99 completed in 21.09 seconds
# simulation            14 completed in 21.18 seconds
# preparation for sim  101 completed in 13.63 seconds
# preparation for sim  185 completed in 15.04 seconds
# preparation for sim   16 completed in 16.21 seconds
# simulation           184 completed in 34.21 seconds
# simulation           100 completed in 21.11 seconds
# simulation            15 completed in 21.27 seconds
# preparation for sim  102 completed in 13.59 seconds
# preparation for sim  186 completed in 14.29 seconds
# preparation for sim   17 completed in 12.53 seconds
# simulation           185 completed in 32.26 seconds
# simulation           101 completed in 21.37 seconds
# simulation            16 completed in 21.17 seconds
# preparation for sim   18 completed in 11.39 seconds
# preparation for sim  103 completed in 10.46 seconds
# preparation for sim  187 completed in 10.44 seconds
# simulation           186 completed in 21.58 seconds
# simulation           102 completed in 21.21 seconds
# simulation            17 completed in 21.39 seconds
# preparation for sim   19 completed in 11.90 seconds
# preparation for sim  104 completed in 11.72 seconds
# preparation for sim  188 completed in 11.78 seconds
# simulation           187 completed in 28.79 seconds
# simulation           103 completed in 21.30 seconds
# simulation            18 completed in 21.27 seconds
# preparation for sim  189 completed in 13.70 seconds
# preparation for sim   20 completed in 14.78 seconds
# preparation for sim  105 completed in 14.38 seconds
# simulation           188 completed in 30.96 seconds
# simulation           104 completed in 21.18 seconds
# simulation            19 completed in 21.26 seconds
# preparation for sim   21 completed in 13.24 seconds
# preparation for sim  106 completed in 13.01 seconds
# preparation for sim  190 completed in 12.94 seconds
# simulation           189 completed in 32.61 seconds
# simulation           105 completed in 21.14 seconds
# simulation            20 completed in 21.24 seconds
# preparation for sim  191 completed in 11.28 seconds
# preparation for sim   22 completed in 12.63 seconds
# preparation for sim  107 completed in 12.60 seconds
# simulation           190 completed in 27.13 seconds
# simulation           106 completed in 21.23 seconds
# simulation            21 completed in 21.31 seconds
# preparation for sim   23 completed in 11.83 seconds
# preparation for sim  192 completed in 11.67 seconds
# preparation for sim  108 completed in 11.87 seconds
# simulation           191 completed in 21.70 seconds
# simulation           107 completed in 21.39 seconds
# simulation            22 completed in 21.66 seconds
# preparation for sim  193 completed in 11.03 seconds
# preparation for sim   24 completed in 11.14 seconds
# preparation for sim  109 completed in 11.23 seconds
# simulation           192 completed in 22.01 seconds
# simulation           108 completed in 21.40 seconds
# simulation            23 completed in 21.32 seconds
# preparation for sim  194 completed in 11.35 seconds
# preparation for sim  110 completed in 11.21 seconds
# preparation for sim   25 completed in 11.17 seconds
# simulation           193 completed in 27.14 seconds
# simulation           109 completed in 21.20 seconds
# simulation            24 completed in 21.28 seconds
# preparation for sim  195 completed in 10.85 seconds
# preparation for sim  111 completed in 11.23 seconds
# preparation for sim   26 completed in 11.25 seconds
# simulation           194 completed in 25.82 seconds
# simulation           110 completed in 21.23 seconds
# simulation            25 completed in 21.28 seconds
# preparation for sim  196 completed in 10.61 seconds
# preparation for sim   27 completed in 10.65 seconds
# preparation for sim  112 completed in 10.89 seconds
# simulation           195 completed in 26.15 seconds
# simulation           111 completed in 21.20 seconds
# simulation            26 completed in 21.27 seconds
# preparation for sim  197 completed in 11.14 seconds
# preparation for sim  113 completed in 11.26 seconds
# preparation for sim   28 completed in 11.46 seconds
# simulation           196 completed in 27.99 seconds
# simulation           112 completed in 21.19 seconds
# simulation            27 completed in 21.31 seconds
# preparation for sim  198 completed in 11.06 seconds
# preparation for sim  114 completed in 10.81 seconds
# preparation for sim   29 completed in 11.08 seconds
# simulation           197 completed in 23.05 seconds
# simulation           113 completed in 21.38 seconds
# simulation            28 completed in 21.30 seconds
# preparation for sim   30 completed in 12.66 seconds
# preparation for sim  199 completed in 13.85 seconds
# preparation for sim  115 completed in 14.11 seconds
# simulation           198 completed in 30.84 seconds
# simulation           114 completed in 21.09 seconds
# simulation            29 completed in 21.25 seconds
# preparation for sim   31 completed in 11.63 seconds
# preparation for sim  200 completed in 11.98 seconds
# preparation for sim  116 completed in 13.73 seconds
# simulation           199 completed in 30.52 seconds
# simulation           115 completed in 21.72 seconds
# simulation            30 completed in 21.22 seconds
# preparation for sim  117 completed in 12.02 seconds
# preparation for sim   32 completed in 11.23 seconds
# preparation for sim  201 completed in 11.69 seconds
# simulation           200 completed in 28.94 seconds
# simulation           116 completed in 21.15 seconds
# simulation            31 completed in 21.26 seconds
# preparation for sim   33 completed in 11.66 seconds
# preparation for sim  202 completed in 11.40 seconds
# preparation for sim  118 completed in 10.76 seconds
# simulation           201 completed in 21.66 seconds
# simulation           117 completed in 21.56 seconds
# simulation            32 completed in 21.97 seconds
# preparation for sim   34 completed in 12.14 seconds
# preparation for sim  203 completed in 12.10 seconds
# preparation for sim  119 completed in 14.62 seconds
# simulation           202 completed in 30.36 seconds
# simulation           118 completed in 21.63 seconds
# simulation            33 completed in 21.86 seconds
# preparation for sim  120 completed in 11.26 seconds
# preparation for sim   35 completed in 11.34 seconds
# preparation for sim  204 completed in 11.42 seconds
# simulation           203 completed in 24.42 seconds
# simulation           119 completed in 21.32 seconds
# simulation            34 completed in 21.37 seconds
# preparation for sim  205 completed in 19.30 seconds
# preparation for sim  121 completed in 19.53 seconds
# preparation for sim   36 completed in 19.15 seconds
# simulation           204 completed in 39.37 seconds
# simulation           120 completed in 21.21 seconds
# simulation            35 completed in 21.27 seconds
# preparation for sim  206 completed in 13.31 seconds
# preparation for sim  122 completed in 13.43 seconds
# preparation for sim   37 completed in 14.43 seconds
# simulation           205 completed in 32.23 seconds
# simulation           121 completed in 21.93 seconds
# simulation            36 completed in 21.97 seconds
# preparation for sim  207 completed in 14.90 seconds
# preparation for sim  123 completed in 16.12 seconds
# preparation for sim   38 completed in 15.62 seconds
# simulation           206 completed in 32.87 seconds
# simulation           122 completed in 21.85 seconds
# simulation            37 completed in 21.55 seconds
# preparation for sim  124 completed in 11.42 seconds
# preparation for sim   39 completed in 11.52 seconds
# preparation for sim  208 completed in 11.30 seconds
# simulation           207 completed in 27.97 seconds
# simulation           123 completed in 21.31 seconds
# simulation            38 completed in 21.28 seconds
# preparation for sim  209 completed in 10.30 seconds
# preparation for sim  125 completed in 10.15 seconds
# preparation for sim   40 completed in 10.14 seconds
# simulation           208 completed in 21.59 seconds
# simulation           124 completed in 21.23 seconds
# simulation            39 completed in 21.49 seconds
# preparation for sim  210 completed in 11.57 seconds
# preparation for sim  126 completed in 10.82 seconds
# preparation for sim   41 completed in 10.65 seconds
# simulation           209 completed in 26.17 seconds
# simulation           125 completed in 21.28 seconds
# simulation            40 completed in 21.29 seconds
# preparation for sim  211 completed in 10.52 seconds
# preparation for sim  127 completed in 10.44 seconds
# preparation for sim   42 completed in 11.00 seconds
# simulation           210 completed in 23.94 seconds
# simulation           126 completed in 21.25 seconds
# simulation            41 completed in 21.42 seconds
# preparation for sim   43 completed in 11.79 seconds
# preparation for sim  212 completed in 10.53 seconds
# preparation for sim  128 completed in 11.14 seconds
# simulation           211 completed in 23.93 seconds
# simulation           127 completed in 21.33 seconds
# simulation            42 completed in 21.29 seconds
# preparation for sim  129 completed in 13.19 seconds
# preparation for sim   44 completed in 13.00 seconds
# preparation for sim  213 completed in 13.01 seconds
# simulation           212 completed in 31.45 seconds
# simulation           128 completed in 21.12 seconds
# simulation            43 completed in 21.19 seconds
# preparation for sim  214 completed in 11.68 seconds
# preparation for sim  130 completed in 11.93 seconds
# preparation for sim   45 completed in 14.13 seconds
# simulation           213 completed in 28.36 seconds
# simulation           129 completed in 21.23 seconds
# simulation            44 completed in 21.27 seconds
# preparation for sim  215 completed in 13.22 seconds
# preparation for sim   46 completed in 14.32 seconds
# preparation for sim  131 completed in 14.36 seconds
# simulation           214 completed in 31.49 seconds
# simulation           130 completed in 21.09 seconds
# simulation            45 completed in 21.20 seconds
# preparation for sim  132 completed in 13.62 seconds
# preparation for sim  216 completed in 15.67 seconds
# preparation for sim   47 completed in 15.46 seconds
# simulation           215 completed in 32.70 seconds
# simulation           131 completed in 21.27 seconds
# simulation            46 completed in 21.38 seconds
# preparation for sim  217 completed in 14.49 seconds
# preparation for sim  133 completed in 15.83 seconds
# preparation for sim   48 completed in 15.91 seconds
# simulation           216 completed in 33.21 seconds
# simulation           132 completed in 21.10 seconds
# simulation            47 completed in 21.27 seconds
# preparation for sim  218 completed in 14.97 seconds
# preparation for sim  134 completed in 14.42 seconds
# preparation for sim   49 completed in 14.38 seconds
# simulation           217 completed in 34.16 seconds
# simulation           133 completed in 21.15 seconds
# simulation            48 completed in 21.20 seconds
# preparation for sim   50 completed in 14.07 seconds
# preparation for sim  219 completed in 13.77 seconds
# preparation for sim  135 completed in 12.92 seconds
# simulation           218 completed in 31.45 seconds
# simulation           134 completed in 21.12 seconds
# simulation            49 completed in 21.27 seconds
# preparation for sim  220 completed in 14.18 seconds
# preparation for sim  136 completed in 13.66 seconds
# preparation for sim   51 completed in 13.85 seconds
# simulation           219 completed in 31.89 seconds
# simulation           135 completed in 21.16 seconds
# simulation            50 completed in 21.12 seconds
# preparation for sim   52 completed in 10.49 seconds
# preparation for sim  221 completed in 10.47 seconds
# preparation for sim  137 completed in 11.87 seconds
# simulation           220 completed in 23.91 seconds
# simulation           136 completed in 21.24 seconds
# simulation            51 completed in 21.29 seconds
# preparation for sim  222 completed in 11.69 seconds
# preparation for sim  138 completed in 11.35 seconds
# preparation for sim   53 completed in 11.57 seconds
# simulation           221 completed in 28.42 seconds
# simulation           137 completed in 21.16 seconds
# simulation            52 completed in 21.20 seconds
# preparation for sim  139 completed in 10.31 seconds
# preparation for sim   54 completed in 10.48 seconds
# preparation for sim  223 completed in 10.20 seconds
# simulation           222 completed in 21.87 seconds
# simulation           138 completed in 21.24 seconds
# simulation            53 completed in 21.37 seconds
# preparation for sim  224 completed in 15.14 seconds
# preparation for sim   55 completed in 13.93 seconds
# preparation for sim  140 completed in 15.04 seconds
# simulation           223 completed in 31.27 seconds
# simulation           139 completed in 21.10 seconds
# simulation            54 completed in 21.32 seconds
# preparation for sim  225 completed in 14.15 seconds
# preparation for sim   56 completed in 13.59 seconds
# preparation for sim  141 completed in 16.28 seconds
# simulation           224 completed in 32.91 seconds
# simulation           140 completed in 21.11 seconds
# simulation            55 completed in 21.26 seconds
# preparation for sim  142 completed in 12.84 seconds
# preparation for sim  226 completed in 14.02 seconds
# preparation for sim   57 completed in 15.10 seconds
# simulation           225 completed in 31.15 seconds
# simulation           141 completed in 21.14 seconds
# simulation            56 completed in 21.28 seconds
# preparation for sim  227 completed in 14.19 seconds
# preparation for sim   58 completed in 16.74 seconds
# preparation for sim  143 completed in 16.55 seconds
# simulation           226 completed in 35.80 seconds
# simulation           142 completed in 21.16 seconds
# simulation            57 completed in 21.17 seconds
# preparation for sim   59 completed in 17.23 seconds
# preparation for sim  228 completed in 16.66 seconds
# preparation for sim  144 completed in 16.84 seconds
# simulation           227 completed in 25.05 seconds
# simulation           143 completed in 21.26 seconds
# simulation            58 completed in 21.87 seconds
# preparation for sim   60 completed in 14.11 seconds
# preparation for sim  229 completed in 14.60 seconds
# preparation for sim  145 completed in 14.83 seconds
# simulation           228 completed in 33.77 seconds
# simulation           144 completed in 21.12 seconds
# simulation            59 completed in 21.36 seconds
# preparation for sim   61 completed in 11.00 seconds
# preparation for sim  230 completed in 14.08 seconds
# preparation for sim  146 completed in 13.84 seconds
# simulation           229 completed in 27.28 seconds
# simulation           145 completed in 21.16 seconds
# simulation            60 completed in 21.42 seconds
# preparation for sim   62 completed in 10.05 seconds
# preparation for sim  231 completed in 10.25 seconds
# preparation for sim  147 completed in 10.78 seconds
# simulation           230 completed in 21.80 seconds
# simulation           146 completed in 21.29 seconds
# simulation            61 completed in 21.30 seconds
# preparation for sim  232 completed in 10.69 seconds
# preparation for sim  148 completed in 10.58 seconds
# preparation for sim   63 completed in 10.57 seconds
# simulation           231 completed in 22.32 seconds
# simulation           147 completed in 21.27 seconds
# simulation            62 completed in 40.23 seconds
# preparation for sim  233 completed in 16.07 seconds
# preparation for sim  149 completed in 16.28 seconds
# preparation for sim   64 completed in 16.36 seconds
# simulation           232 completed in 33.02 seconds
# simulation           148 completed in 21.92 seconds
# simulation            63 completed in 21.82 seconds
# preparation for sim   65 completed in 11.91 seconds
# preparation for sim  234 completed in 11.60 seconds
# preparation for sim  150 completed in 13.77 seconds
# simulation           233 completed in 26.17 seconds
# simulation           149 completed in 21.99 seconds
# simulation            64 completed in 21.69 seconds
# preparation for sim  151 completed in 11.13 seconds
# preparation for sim  235 completed in 11.22 seconds
# preparation for sim   66 completed in 11.21 seconds
# simulation           234 completed in 22.98 seconds
# simulation           150 completed in 21.90 seconds
# simulation            65 completed in 22.08 seconds
# preparation for sim   67 completed in 12.88 seconds
# preparation for sim  152 completed in 11.88 seconds
# preparation for sim  236 completed in 11.23 seconds
# simulation           235 completed in 22.31 seconds
# simulation           151 completed in 21.78 seconds
# simulation            66 completed in 22.08 seconds
# preparation for sim   68 completed in 13.11 seconds
# preparation for sim  153 completed in 12.88 seconds
# preparation for sim  237 completed in 12.10 seconds
# simulation           236 completed in 31.19 seconds
# simulation           152 completed in 21.66 seconds
# simulation            67 completed in 21.86 seconds
# preparation for sim  154 completed in 10.55 seconds
# preparation for sim   69 completed in 10.65 seconds
# preparation for sim  238 completed in 10.40 seconds
# simulation           237 completed in 23.57 seconds
# simulation           153 completed in 21.27 seconds
# simulation            68 completed in 21.24 seconds
# preparation for sim  155 completed in 14.99 seconds
# preparation for sim   70 completed in 15.48 seconds
# preparation for sim  239 completed in 15.46 seconds
# simulation           238 completed in 28.07 seconds
# simulation           154 completed in 21.36 seconds
# simulation            69 completed in 21.35 seconds
# preparation for sim  156 completed in 11.43 seconds
# preparation for sim   71 completed in 14.85 seconds
# preparation for sim  240 completed in 14.60 seconds
# simulation           239 completed in 27.62 seconds
# simulation           155 completed in 21.22 seconds
# simulation            70 completed in 21.63 seconds
# preparation for sim   72 completed in 12.90 seconds
# preparation for sim  241 completed in 12.90 seconds
# preparation for sim  157 completed in 11.89 seconds
# simulation           240 completed in 22.17 seconds
# simulation           156 completed in 21.31 seconds
# simulation            71 completed in 21.38 seconds
# preparation for sim   73 completed in 13.56 seconds
# preparation for sim  242 completed in 13.50 seconds
# preparation for sim  158 completed in 13.59 seconds
# simulation           241 completed in 21.80 seconds
# simulation           157 completed in 21.33 seconds
# simulation            72 completed in 36.07 seconds
# preparation for sim  243 completed in 18.20 seconds
# preparation for sim   74 completed in 18.29 seconds
# preparation for sim  159 completed in 18.32 seconds
# simulation           242 completed in 37.38 seconds
# simulation           158 completed in 21.12 seconds
# simulation            73 completed in 21.38 seconds
# preparation for sim   75 completed in 17.04 seconds
# preparation for sim  244 completed in 17.08 seconds
# preparation for sim  160 completed in 17.22 seconds
# simulation           243 completed in 36.27 seconds
# simulation           159 completed in 21.23 seconds
# simulation            74 completed in 21.21 seconds
# preparation for sim  245 completed in 11.12 seconds
# preparation for sim   76 completed in 12.21 seconds
# preparation for sim  161 completed in 14.33 seconds
# simulation           244 completed in 26.07 seconds
# simulation           160 completed in 21.19 seconds
# simulation            75 completed in 21.35 seconds
# preparation for sim  162 completed in 10.40 seconds
# preparation for sim  246 completed in 10.92 seconds
# preparation for sim   77 completed in 10.78 seconds
# simulation           245 completed in 22.79 seconds
# simulation           161 completed in 21.36 seconds
# simulation            76 completed in 21.30 seconds
# preparation for sim  247 completed in 10.47 seconds
# preparation for sim   78 completed in 10.57 seconds
# preparation for sim  163 completed in 10.21 seconds
# simulation           246 completed in 21.72 seconds
# simulation           162 completed in 21.33 seconds
# simulation            77 completed in 21.40 seconds
# preparation for sim  248 completed in 13.65 seconds
# preparation for sim   79 completed in 14.69 seconds
# preparation for sim  164 completed in 15.26 seconds
# simulation           247 completed in 32.55 seconds
# simulation           163 completed in 21.16 seconds
# simulation            78 completed in 21.24 seconds
# preparation for sim  165 completed in 10.80 seconds
# preparation for sim  249 completed in 13.94 seconds
# preparation for sim   80 completed in 14.43 seconds
# simulation           248 completed in 27.64 seconds
# simulation           164 completed in 21.22 seconds
# simulation            79 completed in 21.31 seconds
# preparation for sim   81 completed in 10.69 seconds
# preparation for sim  250 completed in 10.62 seconds
# preparation for sim  166 completed in 12.20 seconds
# simulation           249 completed in 24.15 seconds
# simulation           165 completed in 21.28 seconds
# simulation            80 completed in 21.37 seconds
# preparation for sim   82 completed in 11.04 seconds
# preparation for sim  167 completed in 10.78 seconds
# preparation for sim  251 completed in 10.73 seconds
# simulation           250 completed in 21.88 seconds
# simulation           166 completed in 21.29 seconds
# simulation            81 completed in 21.44 seconds
# preparation for sim   83 completed in 14.27 seconds
# preparation for sim  168 completed in 14.53 seconds
# preparation for sim  252 completed in 13.94 seconds
# simulation           251 completed in 33.52 seconds
# simulation           167 completed in 21.22 seconds
# simulation            82 completed in 21.43 seconds
# preparation for sim   84 completed in 14.47 seconds
# preparation for sim  169 completed in 17.09 seconds
# preparation for sim  253 completed in 16.59 seconds
# simulation           252 completed in 34.16 seconds
# simulation           168 completed in 21.18 seconds
# simulation            83 completed in 21.57 seconds
# preparation for sim  170 completed in 13.60 seconds
# preparation for sim  254 completed in 13.21 seconds
# preparation for sim   85 completed in 16.23 seconds
# simulation           253 completed in 32.71 seconds
# simulation           169 completed in 21.32 seconds
# simulation            84 completed in 21.22 seconds
# simulation           254 completed in 21.36 seconds
# simulation           170 completed in 21.37 seconds
# preparation for sim  255 completed in 10.02 seconds
# simulation            85 completed in 21.56 seconds
# simulation           255 completed in 21.41 seconds
# successfully joined 3 preparation processes and 1 run process

# %% [markdown]
# # Reconstruction

# %%
test_experiment.add_results()

# %%
test_reconstruction = reconstruction.DAS(experiment=test_experiment)

# %%
signals = test_reconstruction.get_signals(
    dimensions=2, matsize=512, downsample=1, workers=16, tgc=10
)
# Out:
# 100%|██████████| 256/256 [00:56<00:00,  4.57it/s]
# 8it [00:20,  2.60s/it]

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))   # 1 row, 2 columns

# --- Image 1: apical 4-chamber ---
axes[0].imshow(signals[0][:, ::-1], vmin=0, vmax=100000, cmap="gray")
axes[0].set_title("im1")
axes[0].set_facecolor("gray")
axes[0].set_xticks([])
axes[0].set_yticks([])

# --- Image 2: apical 2-chamber ---
axes[1].imshow(signals[1][:, ::-1], vmin=0, vmax=100000, cmap="gray")
axes[1].set_title("im2")
axes[1].set_facecolor("gray")
axes[1].set_xticks([])
axes[1].set_yticks([])

plt.tight_layout()
plt.show()

# %%
signals = test_reconstruction.plot_scatter()
