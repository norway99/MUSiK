# %%
import sys
sys.path.append('../utils')
sys.path.append('../core')
sys.path.append('../')
import numpy as np
import scipy
import tqdm
import utils
import geometry
from core import *

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import glob

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
test_phantom = phantom.Phantom(source_path = None,
            voxel_dims = (0.5e-3,0.5e-3,0.5e-3),
            matrix_dims = (150,150,100),
            baseline = (1500, 1000),
            seed = 5678,)

blood = tissue.Tissue(name='blood', c=1578, rho=1060, sigma=5.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(name='myocardium', c=1561.3, rho=1081, sigma=50, scale=0.0001, label=2)
fat = tissue.Tissue(name='fat', c=1450, rho=920, sigma=0, scale=1, label=3)

pos = 0.02

# test_phantom.add_tissue_sphere((pos,-pos,0), 2, blood)
# test_phantom.add_tissue_sphere((pos,0,0), 4, blood)
# test_phantom.add_tissue_sphere((pos,pos,0), 8, blood)

# test_phantom.add_tissue_sphere((-pos,n-pos,0), 4, fat)
# test_phantom.add_tissue_sphere((-pos,0,0), 8, fat)
# test_phantom.add_tissue_sphere((-pos,pos,0), 2, fat)

# test_phantom.add_tissue_sphere((0,-pos,0), 8, myocardium)
# test_phantom.add_tissue_sphere((0,0,0), 2, myocardium)
# test_phantom.add_tissue_sphere((0,pos,0), 4, myocardium)

test_phantom.add_tissue(fat, mask=np.ones(test_phantom.matrix_dims))
test_phantom.add_tissue_sphere((-0.01,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.01,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.02,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.03,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.04,-0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.025, 0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0225, 0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0175, 0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125, 0,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.005,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.015,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.02,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.025,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0125,0.03,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0075,0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((0.0025,0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((-0.0025,0.01,0), 1, myocardium)
test_phantom.add_tissue_sphere((-0.0075,0.01,0), 1, myocardium)


test_phantom.set_default_tissue('fat')
test = test_phantom.get_complete()
# test_phantom.add_tissue_sphere((0,-pos,0), 4, myocardium)

# %%
plt.imshow(test[0,:,:,test_phantom.matrix_dims[2]//2])
x = test_phantom.mask
print(np.sum(np.where(x != 3, 1, 0)))
# Out:
# 133

# %%
num_transducers = 3
transducers = [transducer.Planewave(max_frequency=1e6,
                                    elements = 32, 
                                    width = 20e-3,
                                    height =  10e-3,
                                    sensor_sampling_scheme = 'not_centroid', 
                                    sweep = np.pi/6,
                                    ray_num = 30, 
                                    imaging_ndims = 2,
                                    focus_elevation = 50e-3,
                                    ) for i in range(num_transducers)]

for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

# %%
cont_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)
cont_transducer_set.assign_pose(0, geometry.Transform([-np.pi/6,0,0], [-0.02,0.01866,0]))
cont_transducer_set.assign_pose(2, geometry.Transform([np.pi/6,0,0], [-0.02,-0.01866,0]))
cont_transducer_set.assign_pose(1, geometry.Transform(translation=[-0.025,0,0]))
# test_transducer_set.assign_pose(0, geometry.Transform([-2*np.pi/6,0,0], [0,0.01,0]))
# test_transducer_set.assign_pose(1, geometry.Transform([2*np.pi/6,0,0], [0,-0.01,0]))
# test_transducer_set.assign_pose(1, geometry.Transform([np.pi/20,0,0], [0,-0.01,0]))

cont_transducer_set.plot_transducer_fovs(scale=0.1)
cont_transducer_set.plot_transducer_coords(scale=0.1)

# %%
num_transducers = 2
transducers_copy = [transducer.Planewave(max_frequency=1e6,
                                    elements = 32, 
                                    width = 20e-3,
                                    height =  10e-3,
                                    sensor_sampling_scheme = 'not_centroid', 
                                    sweep = np.pi/6,
                                    ray_num = 30, 
                                    imaging_ndims = 2,
                                    focus_elevation = 50e-3,
                                    ) for i in range(num_transducers)]

for t in transducers_copy:
    t.make_sensor_coords(test_phantom.baseline[0])
gap_transducer_set = transducer_set.TransducerSet(transducers_copy, seed=8888)
gap_transducer_set.assign_pose(0, geometry.Transform([-np.pi/6,0,0], [-0.02,0.01866,0]))
gap_transducer_set.assign_pose(1, geometry.Transform([np.pi/6,0,0], [-0.02,-0.01866,0]))

gap_transducer_set.plot_transducer_fovs(scale=0.1)
gap_transducer_set.plot_transducer_coords(scale=0.1)

# %%
extended_sensor = sensor.Sensor(transducer_set=cont_transducer_set, aperture_type='extended_aperture')
tar_sensor = sensor.Sensor(transducer_set=cont_transducer_set, aperture_type='transmit_as_receive')
gap_sensor = sensor.Sensor(transducer_set=gap_transducer_set, aperture_type='extended_aperture')

# %%
simprops = simulation.SimProperties(
                grid_size       = (80e-3,80e-3,30e-3),
                voxel_size      = (0.5e-3,0.5e-3,0.5e-3),
                PML_size        = (16,8,8),
                PML_alpha       = 2,
                t_end           = 12e-5,           # [s]
                bona            = 6,               # parameter b/a determining degree of nonlinear acoustic effects
                alpha_coeff     = 0.5, 	           # [dB/(MHz^y cm)]
                alpha_power     = 1.5,
                grid_lambda     = 2,
                )

# %%
tar_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/psf_tar_aperture',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = cont_transducer_set,
                 sensor          = tar_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 2,
                 additional_keys = ['p_max']
                 )

extended_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/psf_extended_aperture',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = cont_transducer_set,
                 sensor          = extended_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 2,
                 additional_keys = ['p_max']
                 )

gap_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/psf_gap_experiment_ea',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = gap_transducer_set,
                 sensor          = gap_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 2,
                 additional_keys = ['p_max']
                 )

tar_experiment.save()
extended_experiment.save()
gap_experiment.save()

# %%
gap_experiment.plot_ray_path(0)

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_tar_aperture')
test_experiment.run(dry=True)
test_experiment.run(repeat=True)
# Out:
# dry run of simulation
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00,  5.06it/s]
# running with 2 workers
# preparation for sim    0 completed in  4.81 seconds
# preparation for sim    1 completed in  4.92 seconds
# preparation for sim    2 completed in  5.06 seconds
# simulation             0 completed in  9.67 seconds
# preparation for sim    3 completed in  4.81 seconds
# preparation for sim    4 completed in  4.97 seconds
# simulation             1 completed in  9.70 seconds
# preparation for sim    5 completed in  5.58 seconds
# simulation             2 completed in  9.98 seconds
# preparation for sim    6 completed in  4.89 seconds
# preparation for sim    7 completed in  4.97 seconds
# simulation             3 completed in  9.93 seconds
# preparation for sim    8 completed in  4.91 seconds
# simulation             4 completed in  9.65 seconds
# simulation             5 completed in  9.38 seconds
# preparation for sim    9 completed in  5.10 seconds
# preparation for sim   10 completed in  4.85 seconds
# simulation             6 completed in  9.57 seconds
# preparation for sim   11 completed in  5.00 seconds
# simulation             7 completed in  9.39 seconds
# preparation for sim   12 completed in  5.00 seconds
# simulation             8 completed in  9.84 seconds
# preparation for sim   13 completed in  5.05 seconds
# simulation             9 completed in  9.90 seconds
# preparation for sim   14 completed in  5.01 seconds
# simulation            10 completed in  9.53 seconds
# preparation for sim   15 completed in  5.14 seconds
# simulation            11 completed in 10.01 seconds
# preparation for sim   16 completed in  5.06 seconds
# simulation            12 completed in  9.53 seconds
# preparation for sim   17 completed in  4.99 seconds
# simulation            13 completed in  9.54 seconds
# preparation for sim   18 completed in  5.53 seconds
# simulation            14 completed in  9.92 seconds
# preparation for sim   19 completed in  4.92 seconds
# simulation            15 completed in  9.78 seconds
# preparation for sim   20 completed in  4.99 seconds
# simulation            16 completed in  9.49 seconds
# preparation for sim   21 completed in  4.98 seconds
# simulation            17 completed in  9.87 seconds
# preparation for sim   22 completed in  5.00 seconds
# simulation            18 completed in  9.53 seconds
# preparation for sim   23 completed in  4.94 seconds
# simulation            19 completed in  9.97 seconds
# preparation for sim   24 completed in  5.06 seconds
# simulation            20 completed in  9.66 seconds
# preparation for sim   25 completed in  5.00 seconds
# simulation            21 completed in  9.69 seconds
# preparation for sim   26 completed in  5.00 seconds
# simulation            22 completed in  9.67 seconds
# preparation for sim   27 completed in  5.04 seconds
# simulation            23 completed in  9.62 seconds
# preparation for sim   28 completed in  5.04 seconds
# simulation            24 completed in  9.46 seconds
# preparation for sim   29 completed in  4.99 seconds
# simulation            25 completed in  9.34 seconds
# preparation for sim   30 completed in  5.03 seconds
# simulation            26 completed in  9.46 seconds
# preparation for sim   31 completed in  4.91 seconds
# simulation            27 completed in  9.52 seconds
# preparation for sim   32 completed in  4.95 seconds
# simulation            28 completed in 10.03 seconds
# preparation for sim   33 completed in  4.93 seconds
# simulation            29 completed in  9.82 seconds
# preparation for sim   34 completed in  4.90 seconds
# simulation            30 completed in  9.80 seconds
# preparation for sim   35 completed in  4.93 seconds
# simulation            31 completed in  9.88 seconds
# preparation for sim   36 completed in  4.88 seconds
# simulation            32 completed in  9.59 seconds
# preparation for sim   37 completed in  4.87 seconds
# simulation            33 completed in  9.64 seconds
# preparation for sim   38 completed in  4.83 seconds
# simulation            34 completed in 10.28 seconds
# preparation for sim   39 completed in  4.87 seconds
# simulation            35 completed in  9.79 seconds
# preparation for sim   40 completed in  4.79 seconds
# simulation            36 completed in  9.91 seconds
# preparation for sim   41 completed in  4.93 seconds
# simulation            37 completed in  9.55 seconds
# preparation for sim   42 completed in  4.84 seconds
# simulation            38 completed in  9.93 seconds
# preparation for sim   43 completed in  4.89 seconds
# simulation            39 completed in  9.93 seconds
# preparation for sim   44 completed in  4.95 seconds
# simulation            40 completed in  9.55 seconds
# preparation for sim   45 completed in  4.94 seconds
# simulation            41 completed in 10.07 seconds
# preparation for sim   46 completed in  4.96 seconds
# simulation            42 completed in  9.56 seconds
# preparation for sim   47 completed in  4.99 seconds
# simulation            43 completed in 10.10 seconds
# preparation for sim   48 completed in  4.99 seconds
# simulation            44 completed in  9.63 seconds
# preparation for sim   49 completed in  5.03 seconds
# simulation            45 completed in 10.03 seconds
# preparation for sim   50 completed in  4.99 seconds
# simulation            46 completed in  9.67 seconds
# preparation for sim   51 completed in  5.02 seconds
# simulation            47 completed in 10.00 seconds
# preparation for sim   52 completed in  4.99 seconds
# simulation            48 completed in  9.64 seconds
# preparation for sim   53 completed in  5.00 seconds
# simulation            49 completed in  9.98 seconds
# preparation for sim   54 completed in  4.99 seconds
# simulation            50 completed in  9.62 seconds
# preparation for sim   55 completed in  4.97 seconds
# simulation            51 completed in 10.07 seconds
# preparation for sim   56 completed in  4.96 seconds
# simulation            52 completed in 10.03 seconds
# preparation for sim   57 completed in  5.01 seconds
# simulation            53 completed in  9.86 seconds
# preparation for sim   58 completed in  4.74 seconds
# simulation            54 completed in  9.58 seconds
# preparation for sim   59 completed in  4.82 seconds
# simulation            55 completed in  9.13 seconds
# preparation for sim   60 completed in  4.82 seconds
# simulation            56 completed in  9.61 seconds
# preparation for sim   61 completed in  4.85 seconds
# simulation            57 completed in  9.13 seconds
# preparation for sim   62 completed in  4.78 seconds
# simulation            58 completed in  9.52 seconds
# preparation for sim   63 completed in  4.81 seconds
# simulation            59 completed in  9.09 seconds
# preparation for sim   64 completed in  4.81 seconds
# simulation            60 completed in  9.57 seconds
# preparation for sim   65 completed in  4.81 seconds
# simulation            61 completed in  9.10 seconds
# preparation for sim   66 completed in  5.44 seconds
# simulation            62 completed in  9.55 seconds
# preparation for sim   67 completed in  6.35 seconds
# simulation            63 completed in 14.06 seconds
# preparation for sim   68 completed in  8.04 seconds
# simulation            64 completed in 23.20 seconds
# preparation for sim   69 completed in 16.74 seconds
# simulation            65 completed in 25.04 seconds
# preparation for sim   70 completed in 10.21 seconds
# simulation            66 completed in 21.24 seconds
# preparation for sim   71 completed in  5.41 seconds
# simulation            67 completed in 13.15 seconds
# preparation for sim   72 completed in  5.93 seconds
# simulation            68 completed in 19.07 seconds
# preparation for sim   73 completed in 14.22 seconds
# simulation            69 completed in 32.62 seconds
# preparation for sim   74 completed in 10.80 seconds
# simulation            70 completed in 22.39 seconds
# preparation for sim   75 completed in  4.82 seconds
# simulation            71 completed in  9.06 seconds
# preparation for sim   76 completed in  4.81 seconds
# simulation            72 completed in  9.10 seconds
# preparation for sim   77 completed in  4.76 seconds
# simulation            73 completed in  9.28 seconds
# simulation            74 completed in  9.10 seconds
# preparation for sim   78 completed in  4.74 seconds
# simulation            75 completed in  9.41 seconds
# preparation for sim   79 completed in  4.73 seconds
# preparation for sim   80 completed in  4.65 seconds
# simulation            76 completed in  9.09 seconds
# preparation for sim   81 completed in  4.82 seconds
# simulation            77 completed in  9.27 seconds
# preparation for sim   82 completed in  4.78 seconds
# simulation            78 completed in  9.31 seconds
# preparation for sim   83 completed in  4.79 seconds
# simulation            79 completed in  9.07 seconds
# preparation for sim   84 completed in  4.84 seconds
# simulation            80 completed in  9.56 seconds
# preparation for sim   85 completed in  4.79 seconds
# simulation            81 completed in  9.41 seconds
# preparation for sim   86 completed in  4.79 seconds
# simulation            82 completed in  9.32 seconds
# preparation for sim   87 completed in  4.86 seconds
# simulation            83 completed in  9.06 seconds
# preparation for sim   88 completed in  4.88 seconds
# simulation            84 completed in  9.57 seconds
# preparation for sim   89 completed in  4.88 seconds
# simulation            85 completed in  9.51 seconds
# simulation            86 completed in  9.27 seconds
# simulation            87 completed in  8.84 seconds
# simulation            88 completed in  9.26 seconds
# simulation            89 completed in  9.17 seconds

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_extended_aperture')
test_experiment.run(dry=True)
test_experiment.run(repeat=True)
# Out:
# dry run of simulation
# 100%|██████████| 3/3 [00:00<00:00,  5.38it/s]
# running with 2 workers
# preparation for sim    0 completed in  4.83 seconds
# preparation for sim    1 completed in  4.98 seconds
# simulation             0 completed in  9.30 seconds
# preparation for sim    2 completed in  4.83 seconds
# preparation for sim    3 completed in  4.68 seconds
# preparation for sim    4 completed in  4.75 seconds
# simulation             1 completed in  9.66 seconds
# preparation for sim    5 completed in  4.95 seconds
# preparation for sim    6 completed in  4.80 seconds
# simulation             2 completed in  9.59 seconds
# simulation             3 completed in  9.59 seconds
# preparation for sim    7 completed in  6.21 seconds
# preparation for sim    8 completed in  4.83 seconds
# simulation             4 completed in  9.18 seconds
# preparation for sim    9 completed in  4.78 seconds
# simulation             5 completed in  9.32 seconds
# preparation for sim   10 completed in  4.75 seconds
# simulation             6 completed in  9.15 seconds
# preparation for sim   11 completed in  4.79 seconds
# simulation             7 completed in  9.50 seconds
# preparation for sim   12 completed in  4.77 seconds
# simulation             8 completed in  9.26 seconds
# preparation for sim   13 completed in  4.82 seconds
# simulation             9 completed in  9.30 seconds
# preparation for sim   14 completed in  4.83 seconds
# simulation            10 completed in  9.45 seconds
# preparation for sim   15 completed in  4.85 seconds
# simulation            11 completed in  9.24 seconds
# preparation for sim   16 completed in  4.83 seconds
# simulation            12 completed in  9.30 seconds
# preparation for sim   17 completed in  4.82 seconds
# simulation            13 completed in  9.46 seconds
# preparation for sim   18 completed in  4.82 seconds
# simulation            14 completed in  9.74 seconds
# preparation for sim   19 completed in  4.82 seconds
# simulation            15 completed in  9.24 seconds
# preparation for sim   20 completed in  4.85 seconds
# simulation            16 completed in  9.23 seconds
# preparation for sim   21 completed in  4.84 seconds
# simulation            17 completed in  9.24 seconds
# simulation            18 completed in  9.26 seconds
# preparation for sim   22 completed in  6.29 seconds
# preparation for sim   23 completed in  4.80 seconds
# simulation            19 completed in  9.26 seconds
# preparation for sim   24 completed in  4.80 seconds
# simulation            20 completed in  9.24 seconds
# preparation for sim   25 completed in  4.83 seconds
# simulation            21 completed in  9.65 seconds
# preparation for sim   26 completed in  4.82 seconds
# simulation            22 completed in  9.27 seconds
# preparation for sim   27 completed in  4.81 seconds
# simulation            23 completed in  9.28 seconds
# preparation for sim   28 completed in  4.78 seconds
# simulation            24 completed in  9.21 seconds
# preparation for sim   29 completed in  4.82 seconds
# simulation            25 completed in  9.29 seconds
# preparation for sim   30 completed in  4.76 seconds
# simulation            26 completed in  9.38 seconds
# preparation for sim   31 completed in  4.74 seconds
# simulation            27 completed in  9.34 seconds
# preparation for sim   32 completed in  4.75 seconds
# simulation            28 completed in  9.37 seconds
# preparation for sim   33 completed in  4.86 seconds
# simulation            29 completed in  9.26 seconds
# preparation for sim   34 completed in  4.76 seconds
# simulation            30 completed in  9.69 seconds
# preparation for sim   35 completed in  4.75 seconds
# simulation            31 completed in  9.33 seconds
# preparation for sim   36 completed in  4.80 seconds
# simulation            32 completed in  9.68 seconds
# preparation for sim   37 completed in  4.76 seconds
# simulation            33 completed in  9.65 seconds
# preparation for sim   38 completed in  4.73 seconds
# simulation            34 completed in  9.62 seconds
# preparation for sim   39 completed in  4.77 seconds
# simulation            35 completed in  9.67 seconds
# preparation for sim   40 completed in  4.81 seconds
# simulation            36 completed in  9.60 seconds
# preparation for sim   41 completed in  4.70 seconds
# simulation            37 completed in  9.69 seconds
# preparation for sim   42 completed in  4.69 seconds
# simulation            38 completed in  9.84 seconds
# preparation for sim   43 completed in  4.71 seconds
# simulation            39 completed in  9.74 seconds
# preparation for sim   44 completed in  4.67 seconds
# simulation            40 completed in  9.62 seconds
# preparation for sim   45 completed in  4.77 seconds
# simulation            41 completed in  9.66 seconds
# preparation for sim   46 completed in  4.75 seconds
# simulation            42 completed in  9.65 seconds
# preparation for sim   47 completed in  4.71 seconds
# simulation            43 completed in  9.64 seconds
# preparation for sim   48 completed in  4.63 seconds
# simulation            44 completed in  9.45 seconds
# preparation for sim   49 completed in  4.68 seconds
# simulation            45 completed in  9.32 seconds
# preparation for sim   50 completed in  4.62 seconds
# simulation            46 completed in  9.41 seconds
# preparation for sim   51 completed in  4.70 seconds
# simulation            47 completed in  9.38 seconds
# preparation for sim   52 completed in  4.67 seconds
# simulation            48 completed in  9.51 seconds
# preparation for sim   53 completed in  4.72 seconds
# simulation            49 completed in  9.30 seconds
# preparation for sim   54 completed in  4.75 seconds
# simulation            50 completed in  9.62 seconds
# preparation for sim   55 completed in  4.65 seconds
# simulation            51 completed in  9.24 seconds
# preparation for sim   56 completed in  4.98 seconds
# simulation            52 completed in 12.47 seconds
# preparation for sim   57 completed in 21.87 seconds
# simulation            53 completed in 39.04 seconds
# preparation for sim   58 completed in 10.22 seconds
# simulation            54 completed in 32.46 seconds
# preparation for sim   59 completed in 13.72 seconds
# simulation            55 completed in 28.39 seconds
# preparation for sim   60 completed in  9.58 seconds
# simulation            56 completed in 33.54 seconds
# preparation for sim   61 completed in  7.15 seconds
# simulation            57 completed in 13.74 seconds
# preparation for sim   62 completed in 22.02 seconds
# simulation            58 completed in 32.14 seconds
# preparation for sim   63 completed in 23.62 seconds
# simulation            59 completed in 55.14 seconds
# preparation for sim   64 completed in 10.94 seconds
# simulation            60 completed in 36.07 seconds
# preparation for sim   65 completed in 16.35 seconds
# simulation            61 completed in 43.10 seconds
# preparation for sim   66 completed in 23.73 seconds
# simulation            62 completed in 41.29 seconds
# preparation for sim   67 completed in 11.00 seconds
# simulation            63 completed in 49.58 seconds
# preparation for sim   68 completed in 20.89 seconds
# simulation            64 completed in 38.05 seconds
# preparation for sim   69 completed in 12.52 seconds
# simulation            65 completed in 36.26 seconds
# preparation for sim   70 completed in 19.96 seconds
# simulation            66 completed in 33.70 seconds
# preparation for sim   71 completed in  6.42 seconds
# simulation            67 completed in 21.38 seconds
# preparation for sim   72 completed in  5.19 seconds
# simulation            68 completed in 10.73 seconds
# preparation for sim   73 completed in 25.60 seconds
# simulation            69 completed in 56.30 seconds
# preparation for sim   74 completed in 14.56 seconds
# simulation            70 completed in 30.16 seconds
# preparation for sim   75 completed in 19.12 seconds
# simulation            71 completed in 46.19 seconds
# preparation for sim   76 completed in 13.63 seconds
# simulation            72 completed in 35.92 seconds
# preparation for sim   77 completed in  7.04 seconds
# simulation            73 completed in 19.67 seconds
# preparation for sim   78 completed in  5.00 seconds
# simulation            74 completed in 10.37 seconds
# preparation for sim   79 completed in 15.99 seconds
# simulation            75 completed in 41.90 seconds
# preparation for sim   80 completed in  7.69 seconds
# simulation            76 completed in 22.63 seconds
# preparation for sim   81 completed in 10.71 seconds
# simulation            77 completed in 23.78 seconds
# preparation for sim   82 completed in 15.29 seconds
# simulation            78 completed in 30.54 seconds
# preparation for sim   83 completed in 13.75 seconds
# simulation            79 completed in 27.36 seconds
# preparation for sim   84 completed in  5.02 seconds
# simulation            80 completed in 11.14 seconds
# preparation for sim   85 completed in 23.85 seconds
# simulation            81 completed in 50.57 seconds
# preparation for sim   86 completed in 18.11 seconds
# simulation            82 completed in 56.72 seconds
# preparation for sim   87 completed in 10.10 seconds
# simulation            83 completed in 23.71 seconds
# preparation for sim   88 completed in 21.62 seconds
# simulation            84 completed in 56.61 seconds
# preparation for sim   89 completed in 10.81 seconds
# simulation            85 completed in 23.93 seconds
# simulation            86 completed in 47.51 seconds
# simulation            87 completed in 34.63 seconds
# simulation            88 completed in 40.41 seconds
# simulation            89 completed in 39.75 seconds

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_gap_experiment_ea')
test_experiment.run(dry=True)
test_experiment.run(repeat=True)
# Out:
# dry run of simulation
# 100%|██████████| 2/2 [00:00<00:00,  3.92it/s]
# running with 2 workers
# preparation for sim    0 completed in  5.68 seconds
# preparation for sim    1 completed in  4.96 seconds
# simulation             0 completed in 10.10 seconds
# preparation for sim    2 completed in  5.89 seconds
# preparation for sim    3 completed in 24.98 seconds
# preparation for sim    4 completed in 22.55 seconds
# simulation             1 completed in 55.69 seconds
# preparation for sim    5 completed in 22.57 seconds
# preparation for sim    6 completed in 11.02 seconds
# simulation             2 completed in 29.51 seconds
# preparation for sim    7 completed in 12.50 seconds
# simulation             3 completed in 49.71 seconds
# preparation for sim    8 completed in 13.96 seconds
# simulation             4 completed in 27.94 seconds
# preparation for sim    9 completed in  7.46 seconds
# simulation             5 completed in 24.93 seconds
# preparation for sim   10 completed in  5.32 seconds
# simulation             6 completed in 12.43 seconds
# preparation for sim   11 completed in  4.89 seconds
# simulation             7 completed in  9.40 seconds
# preparation for sim   12 completed in  4.82 seconds
# simulation             8 completed in  9.53 seconds
# preparation for sim   13 completed in  4.77 seconds
# simulation             9 completed in  9.52 seconds
# preparation for sim   14 completed in  4.85 seconds
# simulation            10 completed in  9.62 seconds
# preparation for sim   15 completed in  4.84 seconds
# simulation            11 completed in  9.50 seconds
# preparation for sim   16 completed in  4.76 seconds
# simulation            12 completed in  9.59 seconds
# preparation for sim   17 completed in  4.76 seconds
# simulation            13 completed in  9.59 seconds
# preparation for sim   18 completed in  4.78 seconds
# simulation            14 completed in  9.35 seconds
# preparation for sim   19 completed in  4.75 seconds
# simulation            15 completed in  9.52 seconds
# preparation for sim   20 completed in  4.76 seconds
# simulation            16 completed in  9.30 seconds
# preparation for sim   21 completed in  4.72 seconds
# simulation            17 completed in  9.55 seconds
# preparation for sim   22 completed in  4.69 seconds
# simulation            18 completed in  9.34 seconds
# simulation            19 completed in  9.63 seconds
# preparation for sim   23 completed in  6.16 seconds
# preparation for sim   24 completed in  4.80 seconds
# simulation            20 completed in  9.38 seconds
# preparation for sim   25 completed in  4.80 seconds
# simulation            21 completed in  9.61 seconds
# preparation for sim   26 completed in  4.76 seconds
# simulation            22 completed in  9.52 seconds
# preparation for sim   27 completed in  4.75 seconds
# simulation            23 completed in  9.32 seconds
# preparation for sim   28 completed in  4.78 seconds
# simulation            24 completed in  9.30 seconds
# preparation for sim   29 completed in  4.76 seconds
# simulation            25 completed in  9.28 seconds
# preparation for sim   30 completed in  4.74 seconds
# simulation            26 completed in  9.20 seconds
# preparation for sim   31 completed in  4.80 seconds
# simulation            27 completed in  9.33 seconds
# preparation for sim   32 completed in  4.79 seconds
# simulation            28 completed in  9.65 seconds
# preparation for sim   33 completed in  4.76 seconds
# simulation            29 completed in  9.24 seconds
# preparation for sim   34 completed in  4.76 seconds
# simulation            30 completed in  9.68 seconds
# preparation for sim   35 completed in  4.73 seconds
# simulation            31 completed in  9.29 seconds
# preparation for sim   36 completed in  4.79 seconds
# simulation            32 completed in  9.57 seconds
# preparation for sim   37 completed in  4.75 seconds
# simulation            33 completed in  9.71 seconds
# preparation for sim   38 completed in  4.76 seconds
# simulation            34 completed in  9.59 seconds
# preparation for sim   39 completed in  4.76 seconds
# simulation            35 completed in  9.67 seconds
# preparation for sim   40 completed in  4.80 seconds
# simulation            36 completed in  9.62 seconds
# preparation for sim   41 completed in  4.75 seconds
# simulation            37 completed in  9.67 seconds
# preparation for sim   42 completed in  4.80 seconds
# simulation            38 completed in  9.86 seconds
# preparation for sim   43 completed in  4.78 seconds
# simulation            39 completed in  9.68 seconds
# preparation for sim   44 completed in  4.79 seconds
# simulation            40 completed in  9.61 seconds
# preparation for sim   45 completed in  4.83 seconds
# simulation            41 completed in  9.70 seconds
# preparation for sim   46 completed in  4.79 seconds
# simulation            42 completed in  9.69 seconds
# preparation for sim   47 completed in  4.77 seconds
# simulation            43 completed in  9.68 seconds
# preparation for sim   48 completed in  4.80 seconds
# simulation            44 completed in  9.60 seconds
# preparation for sim   49 completed in  4.81 seconds
# simulation            45 completed in  9.23 seconds
# preparation for sim   50 completed in  4.81 seconds
# simulation            46 completed in  9.65 seconds
# preparation for sim   51 completed in  4.75 seconds
# simulation            47 completed in  9.71 seconds
# preparation for sim   52 completed in  4.76 seconds
# simulation            48 completed in  9.63 seconds
# preparation for sim   53 completed in  4.72 seconds
# simulation            49 completed in  9.62 seconds
# preparation for sim   54 completed in  4.80 seconds
# simulation            50 completed in  9.52 seconds
# preparation for sim   55 completed in  4.76 seconds
# simulation            51 completed in  9.67 seconds
# preparation for sim   56 completed in  4.84 seconds
# simulation            52 completed in  9.58 seconds
# preparation for sim   57 completed in  4.74 seconds
# simulation            53 completed in  9.30 seconds
# preparation for sim   58 completed in  5.00 seconds
# simulation            54 completed in  9.64 seconds
# preparation for sim   59 completed in  4.91 seconds
# simulation            55 completed in  9.63 seconds
# simulation            56 completed in  9.32 seconds
# simulation            57 completed in  9.24 seconds
# simulation            58 completed in  9.23 seconds
# simulation            59 completed in  9.22 seconds

# %% [markdown]
# # Reconstruction

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_tar_aperture')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00,  4.74it/s]

# %%
images1 = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True, combine=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 1063344.68it/s]

# %%
image1 = np.sum(images1, axis=0)
image1t1 = np.sum(images1[:len(images1)//3], axis=0)
image1t2 = np.sum(images1[len(images1)//3:2*len(images1)//3], axis=0)
image1t3 = np.sum(images1[2*len(images1)//3:], axis=0)

# %%
plt.imshow(image1[:,:,image1.shape[2]//2])
plt.colorbar()

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_extended_aperture')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
# 100%|██████████| 3/3 [00:00<00:00,  4.34it/s]

# %%
image2 = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 1072407.27it/s]

# %%
plt.imshow(image2[:,:,image2.shape[2]//2])
plt.colorbar()

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_gap_experiment_ea')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
#  50%|█████     | 1/2 [00:00<00:00,  4.54it/s]
# 100%|██████████| 2/2 [00:00<00:00,  6.05it/s]

# %%
image3 = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 1133595.68it/s]

# %%
plt.imshow(image3[:,:,image3.shape[2]//2])
plt.colorbar()

# %%
pfield = utils.load_array('1mhz_pfield.npz')

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_tar_aperture')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
# 100%|██████████| 3/3 [00:00<00:00,  4.66it/s]

# %%
images1_ap = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True, pressure_field=pfield, combine=False)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 1091003.93it/s]

# %%
image1_ap = np.sum(images1_ap, axis=0)
image1t1_ap = np.sum(images1_ap[:len(images1_ap)//3], axis=0)
image1t2_ap = np.sum(images1_ap[len(images1_ap)//3:2*len(images1_ap)//3], axis=0)
image1t3_ap = np.sum(images1_ap[2*len(images1_ap)//3:], axis=0)

# %%
plt.imshow(image1[:,:,image1.shape[2]//2])
plt.colorbar()

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_extended_aperture')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
#   0%|          | 0/3 [00:00<?, ?it/s]
# 100%|██████████| 3/3 [00:00<00:00,  4.48it/s]

# %%
image2_ap = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True, pressure_field=pfield)
# Out:
# 100%|██████████| 90/90 [00:00<00:00, 1087859.83it/s]

# %%
plt.imshow(image2[:,:,image2.shape[2]//2])
plt.colorbar()

# %%
test_experiment = experiment.Experiment.load('../experiment_files/psf_gap_experiment_ea')
test_experiment.run(dry=True)
test_experiment.add_results()
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
# Out:
# dry run of simulation
# 100%|██████████| 2/2 [00:00<00:00,  6.21it/s]

# %%
image3_ap = test_reconstruction.compound(workers=24, resolution_multiplier=2, local=True, pressure_field=pfield)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 1103764.21it/s]

# %%
plt.imshow(image3[:,:,image3.shape[2]//2])
plt.colorbar()

# %%
psf = 20 * np.log10(image1 / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('tar aperture')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_tar_aperture.png', dpi=300)
psf = 20 * np.log10(image1_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('tar aperture apodized')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_tar_aperture_apodized.png', dpi=300)
fig, ax = plt.subplots(1,3, figsize=(15,5))

psf = 20 * np.log10(image1t1 / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[0].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[0].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[0].clabel(CS, inline=True, fontsize=10)
ax[0].set_title('tar aperture t1')
ax[0].set_xticks([])
ax[0].set_yticks([])

psf = 20 * np.log10(image1t2 / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[1].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[1].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[1].clabel(CS, inline=True, fontsize=10)
ax[1].set_title('tar aperture t2')
ax[1].set_xticks([])
ax[1].set_yticks([])

psf = 20 * np.log10(image1t3 / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[2].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[2].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[2].clabel(CS, inline=True, fontsize=10)
ax[2].set_title('tar aperture t3')
ax[2].set_xticks([])
ax[2].set_yticks([])



plt.savefig('psf_tar_aperture_components.png', dpi=300)
fig, ax = plt.subplots(1,3, figsize=(15,5))

psf = 20 * np.log10(image1t1_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[0].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[0].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[0].clabel(CS, inline=True, fontsize=10)
ax[0].set_title('tar aperture apodized t1')
ax[0].set_xticks([])
ax[0].set_yticks([])

psf = 20 * np.log10(image1t2_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[1].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[1].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[1].clabel(CS, inline=True, fontsize=10)
ax[1].set_title('tar aperture apodized t2')
ax[1].set_xticks([])
ax[1].set_yticks([])

psf = 20 * np.log10(image1t3_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

ax[2].imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax[2].contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax[2].clabel(CS, inline=True, fontsize=10)
ax[2].set_title('tar aperture apodized t3')
ax[2].set_xticks([])
ax[2].set_yticks([])



plt.savefig('psf_tar_aperture_apodized_components.png', dpi=300)
psf = 20 * np.log10(image2 / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('extended aperture')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_extended_aperture.png', dpi=300)
psf = 20 * np.log10(image2_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('extended aperture apodized')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_extended_aperture_apodized.png', dpi=300)
psf = 20 * np.log10(image3 / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('gap extended aperture')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_gap_extended_aperture.png', dpi=300)
psf = 20 * np.log10(image3_ap / 1000000)
image = psf[:,:,psf.shape[2]//2]

fig, ax = plt.subplots()

ax.imshow(image, cmap='gray_r')
gridshape = test_reconstruction.phantom.matrix_dims * test_reconstruction.phantom.voxel_dims
x = np.linspace(-gridshape[0]//2, gridshape[0]//2, image.shape[0])
y = np.linspace(-gridshape[1]//2, gridshape[1]//2, image.shape[1])
X, Y = np.meshgrid(x, y)
CS = ax.contour(image, cmap='plasma', linewidths=0.5, levels = [-30,-20,-15,-10,-5,0,])
ax.clabel(CS, inline=True, fontsize=10)
ax.set_title('gap extended aperture apodized')
ax.set_xticks([])
ax.set_yticks([])
plt.savefig('psf_gap_extended_aperture_apodized.png', dpi=300)
