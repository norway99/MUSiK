# %%
import sys
sys.path.append('../utils')
sys.path.append('../core')
sys.path.append('../')
import numpy as np
import scipy
import tqdm
import utils
import geometry
from core import *

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import glob

# %%
test_phantom = phantom.Phantom(source_path = None,
            voxel_dims = (0.5e-3,0.5e-3,0.5e-3),
            matrix_dims = (100,100,100),
            baseline = (1500, 1000),
            seed = 5678,)

blood = tissue.Tissue(name='blood', c=1578, rho=1060, sigma=5.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(name='myocardium', c=1561.3, rho=1081, sigma=30, scale=0.0001, label=2)
fat = tissue.Tissue(name='fat', c=1450, rho=920, sigma=10, scale=0.0001, label=3)

pos = 0.6

# test_phantom.add_tissue_sphere((pos,-pos,0), 2, blood)
# test_phantom.add_tissue_sphere((pos,0,0), 4, blood)
# test_phantom.add_tissue_sphere((pos,pos,0), 8, blood)

# test_phantom.add_tissue_sphere((-pos,-pos,0), 4, fat)
# test_phantom.add_tissue_sphere((-pos,0,0), 8, fat)
# test_phantom.add_tissue_sphere((-pos,pos,0), 2, fat)

# test_phantom.add_tissue_sphere((0,-pos,0), 8, myocardium)
# test_phantom.add_tissue_sphere((0,0,0), 2, myocardium)
# test_phantom.add_tissue_sphere((0,pos,0), 4, myocardium)

test_phantom.add_tissue_sphere((pos,0,0), 4, myocardium)
# test_phantom.add_tissue_sphere((0,-pos,0), 4, myocardium)

# %%
plt.imshow(test_phantom.get_complete()[0,:,:,test_phantom.matrix_dims[2]//2])

# %%
transducers = [transducer.Focused(max_frequency = 2e6,
                                  elements = 32, 
                                  width = 20e-3,
                                  height =  20e-3,
                                  sensor_sampling_scheme = 'not_centroid', 
                                  sweep = np.pi/6,
                                  ray_num = 5, 
                                  imaging_ndims = 2,
                                  focus_azimuth = 50-3,
                                  focus_elevation = 50-3,
    ) for i in range(2)]

for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

# %%
test_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)
test_transducer_set.generate_extrinsics(shape="spherical", extrinsics_kwargs={'r_mean': 50e-3, 'view_std': 0, 'yaw_fraction': 0.5, 'pitch_fraction': 0, 'roll_fraction': 0})
test_transducer_set.assign_pose(0, geometry.Transform([0,0,0], [0,0,0]))
test_transducer_set.plot_transducer_fovs(scale=0.1)
test_transducer_set.plot_transducer_coords(scale=0.1)

# %%
# test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='pressure_field')
test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='transmit_as_receive')
# test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='extended_aperture')

# %%
simprops = simulation.SimProperties(
                grid_size   = (65e-3,60e-3,20e-3),
                voxel_size  = (0.1e-3,0.1e-3,0.1e-3),
                PML_size    = (32,8,8),
                PML_alpha   = 2,
                t_end       = 12e-5,           # [s]
                bona        = 6,               # parameter b/a determining degree of nonlinear acoustic effects
                alpha_coeff = 0.5, 	           # [dB/(MHz^y cm)]
                alpha_power = 1.5,
                )

# %%
test_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/planewave_test_04',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = test_transducer_set,
                 sensor          = test_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 1,
                 additional_keys = ['p_max']
                 )

test_experiment.save()

# %%
test_experiment.plot_ray_path(0)

# %%
test_experiment = experiment.Experiment.load('../experiment_files/planewave_test_04')
test_experiment.run(dry=True)
# Out:
# Number of simulation results (0) is less than the expected number of simulation results (10), are you sure the simulation finished running?
# dry run of simulation
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]

# %%
test_experiment.run(repeat=True)
# Out:
# running with 1 workers
#
# preparation for sim    0 completed in            4.34 seconds
#
# preparation for sim    1 completed in            5.20 seconds
#
# preparation for sim    2 completed in           18.63 seconds
#
# preparation for sim    3 completed in            7.93 seconds
#
# preparation for sim    4 completed in           12.37 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                            512 x 324 x 162 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   2543 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.27s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.20s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                            2664MB │
# │ Current device memory in use:                         11730MB │
# │ Expected output file size:                              109MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.031s  │     39.481s  │  14/05/24 11:38:37 │
# │     5%   │        4.809s  │     89.986s  │  14/05/24 11:39:32 │
# │    10%   │        9.486s  │     84.748s  │  14/05/24 11:39:31 │
# │    15%   │       13.220s  │     74.557s  │  14/05/24 11:39:25 │
# │    20%   │       18.108s  │     72.182s  │  14/05/24 11:39:28 │
# │    25%   │       23.007s  │     68.839s  │  14/05/24 11:39:29 │
# │    30%   │       27.922s  │     65.018s  │  14/05/24 11:39:31 │
# │    35%   │       32.849s  │     60.800s  │  14/05/24 11:39:31 │
# │    40%   │       37.807s  │     56.543s  │  14/05/24 11:39:32 │
# │    45%   │       42.847s  │     52.231s  │  14/05/24 11:39:33 │
# │    50%   │       47.879s  │     47.766s  │  14/05/24 11:39:33 │
# │    55%   │       52.895s  │     43.185s  │  14/05/24 11:39:34 │
# │    60%   │       57.901s  │     38.525s  │  14/05/24 11:39:34 │
# │    65%   │       62.892s  │     33.803s  │  14/05/24 11:39:34 │
# │    70%   │       67.937s  │     29.012s  │  14/05/24 11:39:35 │
# │    75%   │       72.890s  │     24.208s  │  14/05/24 11:39:35 │
# │    80%   │       77.841s  │     19.384s  │  14/05/24 11:39:35 │
# │    85%   │       82.790s  │     14.545s  │  14/05/24 11:39:35 │
# │    90%   │       87.685s  │      9.688s  │  14/05/24 11:39:35 │
# │    95%   │       92.582s  │      4.826s  │  14/05/24 11:39:35 │
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                          97.61s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                               2664MB │
# │ Peak device memory in use:                            11730MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                 100.17s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      0 completed in 154.16 seconds
# preparation for sim    5 completed in            5.00 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                            512 x 324 x 162 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   2543 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.20s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.17s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                            2664MB │
# │ Current device memory in use:                         11730MB │
# │ Expected output file size:                              109MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.039s  │     49.535s  │  14/05/24 11:40:56 │
# │     5%   │        4.935s  │     92.351s  │  14/05/24 11:41:44 │
# │    10%   │        9.826s  │     87.784s  │  14/05/24 11:41:43 │
# │    15%   │       14.699s  │     82.895s  │  14/05/24 11:41:43 │
# │    20%   │       19.587s  │     78.080s  │  14/05/24 11:41:44 │
# │    25%   │       24.462s  │     73.193s  │  14/05/24 11:41:44 │
# │    30%   │       29.357s  │     68.358s  │  14/05/24 11:41:44 │
# │    35%   │       34.271s  │     63.433s  │  14/05/24 11:41:44 │
B │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                  98.63s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      8 completed in 125.70 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                            512 x 324 x 162 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   2543 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.21s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.13s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                            2664MB │
# │ Current device memory in use:                         11730MB │
# │ Expected output file size:                              109MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.040s  │     51.112s  │  14/05/24 11:58:05 │
# │     5%   │        3.784s  │     70.817s  │  14/05/24 11:58:27 │
# │    10%   │        8.659s  │     77.360s  │  14/05/24 11:58:39 │
# │    15%   │       13.547s  │     76.399s  │  14/05/24 11:58:43 │
# │    20%   │       18.418s  │     73.419s  │  14/05/24 11:58:45 │
# │    25%   │       23.310s  │     69.747s  │  14/05/24 11:58:46 │
# │    30%   │       28.204s  │     65.674s  │  14/05/24 11:58:47 │
# │    35%   │       33.124s  │     61.309s  │  14/05/24 11:58:48 │
# │    40%   │       38.026s  │     56.871s  │  14/05/24 11:58:48 │
# │    45%   │       42.911s  │     52.309s  │  14/05/24 11:58:48 │
# │    50%   │       47.796s  │     47.683s  │  14/05/24 11:58:48 │
# │    55%   │       52.689s  │     43.017s  │  14/05/24 11:58:49 │
# │    60%   │       57.571s  │     38.305s  │  14/05/24 11:58:49 │
# │    65%   │       62.458s  │     33.570s  │  14/05/24 11:58:49 │
# │    70%   │       67.385s  │     28.777s  │  14/05/24 11:58:49 │
# │    75%   │       72.268s  │     24.001s  │  14/05/24 11:58:50 │
# │    80%   │       77.156s  │     19.213s  │  14/05/24 11:58:50 │
# │    85%   │       82.044s  │     14.414s  │  14/05/24 11:58:50 │
# │    90%   │       86.943s  │      9.606s  │  14/05/24 11:58:49 │
# │    95%   │       91.823s  │      4.787s  │  14/05/24 11:58:49 │
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                          96.82s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                               2664MB │
# │ Peak device memory in use:                            11730MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                  98.84s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      9 completed in 125.49 seconds

# %%
test_experiment.add_results()

# %%
# test_reconstruction = reconstruction.Compounding(experiment=test_experiment)
test_reconstruction = reconstruction.DAS(experiment=test_experiment)

# %%
# image = test_reconstruction.compound()
# Out:
# 100%|██████████| 10/10 [12:22<00:00, 74.29s/it]

# %%
image.shape
# Out:
# (134, 134, 134)

# %%
test_reconstruction.results

# %%
element_15 = np.array([test_reconstruction.results[i][1][15] for i in range(len(test_reconstruction.results))])
element_0 = np.array([test_reconstruction.results[i][1][0] for i in range(len(test_reconstruction.results))])

# %%
plt.plot(element_15.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7936051eb880>,
#  <matplotlib.lines.Line2D at 0x7936051ebd30>,
#  <matplotlib.lines.Line2D at 0x7936051eb190>,
#  <matplotlib.lines.Line2D at 0x7936051eb430>,
#  <matplotlib.lines.Line2D at 0x7936051eb1c0>,
#  <matplotlib.lines.Line2D at 0x7936051eb280>,
#  <matplotlib.lines.Line2D at 0x793605194760>,
#  <matplotlib.lines.Line2D at 0x793605194640>,
#  <matplotlib.lines.Line2D at 0x793605194370>,
#  <matplotlib.lines.Line2D at 0x793605194be0>]

# %%
plt.plot(element_0.T)
# Out:
# [<matplotlib.lines.Line2D at 0x7936054ee0a0>,
#  <matplotlib.lines.Line2D at 0x7936054ee370>,
#  <matplotlib.lines.Line2D at 0x7936045aa550>,
#  <matplotlib.lines.Line2D at 0x793605490ac0>,
#  <matplotlib.lines.Line2D at 0x7936051b9190>,
#         869620.  , 894439.25, 881192.2 , 848194.1 , 849628.4 , 821125.3 ,
#         764737.06, 764732.4 , 761986.6 , 750672.44, 752778.8 , 773813.94,
#         744493.3 , 728541.5 , 728540.3 , 515544.72, 835133.2 , 754362.25,
#         765347.94, 800075.7 , 833168.6 , 845777.1 , 855724.25, 896689.56,
#         896690.6 , 911001.2 , 891209.8 , 826395.3 , 782568.6 , 740490.44,
#         728873.9 , 728872.75, 358030.7 , 582920.  , 516622.12, 520891.06,
#         543274.3 , 560554.6 , 560223.7 , 593761.5 , 620277.06, 620277.56,
#         631490.7 , 689049.4 , 750630.7 , 810638.1 , 802801.25, 732417.1 ,
#         732415.94], dtype=float32))

# %%
plt.imshow(image[:,:,image.shape[2]//2])
plt.colorbar()

# %%
plt.imshow(test_phantom.get_complete()[0,:,:,test_phantom.matrix_dims[2]//2])

# %%
plt.imshow(image[image.shape[0]//2,:,:])
plt.colorbar()

# %%
plt.imshow(image[:,image.shape[1]//2,:])
plt.colorbar()

# %%
plt.imshow(test_phantom.get_complete()[0,:,:,test_phantom.matrix_dims[2]//2])

# %%
image, signals = test_reconstruction.get_image(dimensions=2, downsample = 1, workers=1)
# Out:
# multiproc time 0.0502934455871582
# 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]

# %%
X = np.linspace(-1, 1, 256)
Y = np.linspace(-1, 1, 256)
X, Y = np.meshgrid(X, Y)

fig, ax = plt.subplots(2,4, figsize=(10,5))
ax[0,0].pcolormesh(X, Y, signals[0], shading='auto', cmap='gray', norm='log')
ax[0,1].pcolormesh(X, Y, signals[1], shading='auto', cmap='gray', norm='log')
# ax[0,2].pcolormesh(X, Y, signals[2], shading='auto', cmap='gray', norm='log')
# ax[0,3].pcolormesh(X, Y, signals[3], shading='auto', cmap='gray', norm='log')
# ax[1,0].pcolormesh(X, Y, signals[4], shading='auto', cmap='gray', norm='log')
# ax[1,1].pcolormesh(X, Y, signals[5], shading='auto', cmap='gray', norm='log')
# ax[1,2].pcolormesh(X, Y, signals[6], shading='auto', cmap='gray', norm='log')
# ax[1,3].pcolormesh(X, Y, signals[7], shading='auto', cmap='gray', norm='log')

for axd1 in ax:
    for a in axd1:
        a.set_aspect('equal')
        a.set_xticks([])
        a.set_yticks([])

fig, ax = plt.subplots(1,1, figsize=(10,10))
ax.pcolormesh(X, Y, image, shading='auto', cmap='gray', norm='log')
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
im = test_reconstruction.results[0][1]

# %%
im.shape
# Out:
# (32, 1272)

# %%
for frame in tqdm.tqdm(range(0,im.shape[-1],10)):
    plt.imshow(im[:,:,frame], cmap='bwr')
    plt.colorbar()
    plt.savefig(f'../experiment_files/outputs/frame_{str(frame).zfill(4)}.png', dpi=50)
    plt.close()
# Out:
#   0%|          | 0/128 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 2
#       1 for frame in tqdm.tqdm(range(0,im.shape[-1],10)):
# ----> 2     plt.imshow(im[:,:,frame], cmap='bwr')
#       3     plt.colorbar()
#       4     plt.savefig(f'../experiment_files/outputs/frame_{str(frame).zfill(4)}.png', dpi=50)
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed
