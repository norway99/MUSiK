# %%
import sys
sys.path.append('../utils')
sys.path.append('../core')
sys.path.append('../')
import numpy as np
import scipy
import tqdm
import utils
import geometry
from core import *

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import glob

# %%
test_phantom = phantom.Phantom(source_path = None,
            voxel_dims = (0.5e-3,0.5e-3,0.5e-3),
            matrix_dims = (100,100,100),
            baseline = (1500, 1000),
            seed = 5678,)

blood = tissue.Tissue(name='blood', c=1578, rho=1060, sigma=5.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(name='myocardium', c=1561.3, rho=1081, sigma=50, scale=0.0001, label=2)
fat = tissue.Tissue(name='fat', c=1450, rho=920, sigma=0, scale=1, label=3)

pos = 0.01

test_phantom.add_tissue(fat, mask=np.ones(test_phantom.matrix_dims))
test_phantom.add_tissue_sphere((pos,0,0), 4, myocardium)
test_phantom.add_tissue_sphere((0,pos,0), 4, myocardium)
test_phantom.set_default_tissue('fat')
test = test_phantom.get_complete()

# %%
plt.imshow(test[0,:,:,test_phantom.matrix_dims[2]//2])
x = test_phantom.mask
print(np.sum(np.where(x != 3, 1, 0)))
# Out:
# 514

# %%
# transducers = [transducer.Planewave(max_frequency=0.5e6,
#                                     elements = 64, 
#                                     width = 40e-3,
#                                     height =  20e-3,
#                                     sensor_sampling_scheme = 'not_centroid', 
#                                     sweep = np.pi/6,
#                                     ray_num = 16, 
#                                     imaging_ndims = 2,
#                                     focus_elevation = 20e-3,
#                                     ) for i in range(1)]

transducers = [transducer.Focused(max_frequency=0.5e6,
                                    elements = 64, 
                                    width = 20e-3,
                                    height =  20e-3,
                                    sensor_sampling_scheme = 'not_centroid', 
                                    sweep = np.pi/4,
                                    ray_num = 16, 
                                    imaging_ndims = 2,
                                    focus_elevation = 15e-3,
                                    focus_azimuth = 15e-3,
                                    ) for i in range(3)]

for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

# %%
test_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)
#test_transducer_set.generate_extrinsics(shape="spherical", extrinsics_kwargs={'r_mean': 1e-3, 'view_std': 0, 'yaw_fraction': 1, 'pitch_fraction': 0, 'roll_fraction': 0})
# test_transducer_set.assign_pose(0, geometry.Transform([-np.pi/6,0,0], [0,0.01,0]))
# test_transducer_set.assign_pose(1, geometry.Transform([np.pi/6,0,0], [0,-0.01,0]))
# test_transducer_set.assign_pose(0, geometry.Transform([-np.pi/20,0,0], [0,0.01,0]))
# test_transducer_set.assign_pose(1, geometry.Transform([np.pi/20,0,0], [0,-0.01,0]))

test_transducer_set.assign_pose(0, geometry.Transform([np.pi/6,0,0], [-0.015,-0.02,0]))
test_transducer_set.assign_pose(1, geometry.Transform([0,0,0], [-0.02, 0,0]))
test_transducer_set.assign_pose(2, geometry.Transform([-np.pi/6,0,0], [-0.015,0.02,0]))
test_transducer_set.plot_transducer_fovs(scale=0.1)
test_transducer_set.plot_transducer_coords(scale=0.1)

# %%
# test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='pressure_field')
test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='extended_aperture')
# test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='transmit_as_receive')

# %%
simprops = simulation.SimProperties(
                grid_size   = (50e-3,50e-3,30e-3),
                voxel_size  = (0.5e-3,0.5e-3,0.5e-3),
                PML_size    = (32,8,8),
                PML_alpha   = 2,
                t_end       = 12e-5,           # [s]
                bona        = 6,               # parameter b/a determining degree of nonlinear acoustic effects
                alpha_coeff = 0.5, 	           # [dB/(MHz^y cm)]
                alpha_power = 1.5,
                )

# %%
test_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/planewave_test_03',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = test_transducer_set,
                 sensor          = test_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 1,
                 additional_keys = []
                 )

test_experiment.save()

# %%
test_experiment.visualize_sensor_mask(index=[slice(0, -1, 1), slice(0, -1, 1), test_phantom.matrix_dims[2]//2])

# %%
test_experiment.plot_ray_path(0)

# %%
test_experiment = experiment.Experiment.load('../experiment_files/planewave_test_03')
test_experiment.run(dry=True)
# Out:
# Number of simulation results (16) is less than the expected number of simulation results (48), are you sure the simulation finished running?
# dry run of simulation
# 100%|██████████| 3/3 [00:00<00:00, 13.88it/s]

# %%
test_experiment.run(repeat=True)
# Out:
# running with 1 workers
#
# preparation for sim    0 completed in  0.58 seconds
# preparation for sim    1 completed in  0.61 seconds
# preparation for sim    2 completed in  0.58 seconds
# simulation             0 completed in  1.31 seconds
# preparation for sim    3 completed in  0.60 seconds
# preparation for sim    4 completed in  0.60 seconds
# preparation for sim    5 completed in  0.66 seconds
# simulation             1 completed in  1.48 seconds
# simulation             2 completed in  1.11 seconds
# simulation             3 completed in  1.12 seconds
# simulation             4 completed in  1.11 seconds
# simulation             5 completed in  1.11 seconds
# preparation for sim    6 completed in  0.56 seconds
# preparation for sim    7 completed in  0.60 seconds
# preparation for sim    8 completed in  0.64 seconds
# simulation             6 completed in  1.43 seconds
# preparation for sim    9 completed in  0.58 seconds
# preparation for sim   10 completed in  0.57 seconds
# preparation for sim   11 completed in  0.65 seconds
# simulation             7 completed in  1.44 seconds
# simulation             8 completed in  1.11 seconds
# simulation             9 completed in  1.13 seconds
# simulation            10 completed in  1.17 seconds
# simulation            11 completed in  1.10 seconds
# preparation for sim   12 completed in  0.56 seconds
# preparation for sim   13 completed in  0.60 seconds
# preparation for sim   14 completed in  0.68 seconds
# simulation            12 completed in  1.45 seconds
# preparation for sim   15 completed in  0.60 seconds
# preparation for sim   16 completed in  0.59 seconds
# simulation            13 completed in  1.29 seconds
# preparation for sim   17 completed in  0.57 seconds
# preparation for sim   18 completed in  0.56 seconds
# simulation            14 completed in  1.09 seconds
# simulation            15 completed in  1.10 seconds
# simulation            16 completed in  1.11 seconds
# simulation            17 completed in  1.11 seconds
# simulation            18 completed in  1.11 seconds
# preparation for sim   19 completed in  0.56 seconds
# preparation for sim   20 completed in  0.61 seconds
# preparation for sim   21 completed in  0.60 seconds
# simulation            19 completed in  1.27 seconds
# preparation for sim   22 completed in  0.58 seconds
# preparation for sim   23 completed in  0.56 seconds
# preparation for sim   24 completed in  0.62 seconds
# simulation            20 completed in  1.48 seconds
# simulation            21 completed in  1.12 seconds
# simulation            22 completed in  1.10 seconds
# simulation            23 completed in  1.12 seconds
# simulation            24 completed in  1.11 seconds
# preparation for sim   25 completed in  0.56 seconds
# preparation for sim   26 completed in  0.58 seconds
# preparation for sim   27 completed in  0.67 seconds
# simulation            25 completed in  1.44 seconds
# preparation for sim   28 completed in  0.60 seconds
# preparation for sim   29 completed in  0.60 seconds
# simulation            26 completed in  1.30 seconds
# preparation for sim   30 completed in  0.58 seconds
# preparation for sim   31 completed in  0.56 seconds
# simulation            27 completed in  1.09 seconds
# simulation            28 completed in  1.10 seconds
# simulation            29 completed in  1.10 seconds
# simulation            30 completed in  1.12 seconds
# simulation            31 completed in  1.21 seconds
# preparation for sim   32 completed in  0.57 seconds
# preparation for sim   33 completed in  0.60 seconds
# preparation for sim   34 completed in  0.59 seconds
# simulation            32 completed in  1.21 seconds
# preparation for sim   35 completed in  0.58 seconds
# preparation for sim   36 completed in  0.57 seconds
# preparation for sim   37 completed in  0.63 seconds
# simulation            33 completed in  1.49 seconds
# simulation            34 completed in  1.14 seconds
# simulation            35 completed in  1.11 seconds
# simulation            36 completed in  1.11 seconds
# simulation            37 completed in  1.14 seconds
# preparation for sim   38 completed in  0.56 seconds
# preparation for sim   39 completed in  0.59 seconds
# preparation for sim   40 completed in  0.67 seconds
# simulation            38 completed in  1.37 seconds
# preparation for sim   41 completed in  0.57 seconds
# preparation for sim   42 completed in  0.60 seconds
# simulation            39 completed in  1.29 seconds
# preparation for sim   43 completed in  0.58 seconds
# preparation for sim   44 completed in  0.56 seconds
# simulation            40 completed in  1.11 seconds
# simulation            41 completed in  1.11 seconds
# simulation            42 completed in  1.13 seconds
# simulation            43 completed in  1.11 seconds
# simulation            44 completed in  1.11 seconds
# preparation for sim   45 completed in  0.55 seconds
# preparation for sim   46 completed in  0.58 seconds
# preparation for sim   47 completed in  0.56 seconds
# simulation            45 completed in  1.12 seconds
# simulation            46 completed in  1.11 seconds
# simulation            47 completed in  1.12 seconds

# %%
test_experiment.add_results()

# %%
test_reconstruction = reconstruction.Compounding(experiment=test_experiment)

# %%
pfield = utils.load_array('1mhz_pfield.npz')

# %%
image_matrices = test_reconstruction.compound(workers=16, resolution_multiplier=4, local=True, combine=False, pressure_field=None)
# Out:
# 100%|██████████| 16/16 [00:00<00:00, 294337.12it/s]

# %%
image = np.sum(image_matrices, axis=0)
plt.imshow(image[:,:,image.shape[2]//2])

# %%
plt.imshow(image_matrices[0][:,:,image_matrices[0].shape[2]//2])

# %%
plt.imshow(image_matrices[7][:,:,image_matrices[7].shape[2]//2])

# %%
plt.imshow(image_matrices[-3][:,:,image_matrices[-3].shape[2]//2])

# %%
plt.imshow(image_matrices[-1][:,:,image_matrices[-1].shape[2]//2])

# %%
plt.imshow(image_matrices[:,:,image_matrices.shape[2]//2])
# plt.imshow(image[:,:,image.shape[2]//2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.imshow(image_matrices[:,:,image_matrices.shape[2]//2])
#       2 # plt.imshow(image[:,:,image.shape[2]//2])
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
from scipy.signal import hilbert2

# %%
local_image_matrix = np.abs(hilbert2(image[:,:,image.shape[2]//2]))

# %%
plt.imshow(local_image_matrix)

# %%
assert False

# %%
plt.imshow(image[:,:,image.shape[2]//2])

# %%
plt.imshow(image[:,:,image.shape[2]//2])

# %%
gm = test_experiment.sensor.visualize(test_phantom, index=[slice(0, -1, 1), slice(0, -1, 1), test_phantom.matrix_dims[2]//2])
