# %%
import sys
sys.path.append('../utils')
sys.path.append('../core')
sys.path.append('../')
import numpy as np
import scipy
import tqdm
import utils
import geometry
from core import *

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import glob

# %%
test_phantom = phantom.Phantom(source_path = None,
            voxel_dims = (0.5e-3,0.5e-3,0.5e-3),
            matrix_dims = (300,300,300),
            baseline = (1500, 1000),
            seed = 5678,)

blood = tissue.Tissue(name='blood', c=1578, rho=1060, sigma=5.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(name='myocardium', c=1561.3, rho=1081, sigma=30, scale=0.0001, label=2)
fat = tissue.Tissue(name='fat', c=1450, rho=920, sigma=10, scale=0.0001, label=3)

pos = 0.7

test_phantom.add_tissue_sphere((pos,-pos,0), 8, blood)
test_phantom.add_tissue_sphere((pos,0,0), 16, blood)
test_phantom.add_tissue_sphere((pos,pos,0), 32, blood)

test_phantom.add_tissue_sphere((-pos,-pos,0), 16, fat)
test_phantom.add_tissue_sphere((-pos,0,0), 32, fat)
test_phantom.add_tissue_sphere((-pos,pos,0), 8, fat)

test_phantom.add_tissue_sphere((0,-pos,0), 32, myocardium)
test_phantom.add_tissue_sphere((0,0,0), 8, myocardium)
test_phantom.add_tissue_sphere((0,pos,0), 16, myocardium)

# %%
plt.imshow(test_phantom.get_complete()[0,:,:,test_phantom.matrix_dims[2]//2])

# %%
transducers = [transducer.Focused(max_frequency = 1e6,
                                  elements = 64, 
                                  width = 20e-3,
                                  height =  20e-3,
                                  sensor_sampling_scheme = 'not_centroid', 
                                  sweep = np.pi/2,
                                  ray_num = 16, 
                                  imaging_ndims = 2,
                                  focus_azimuth = 75e-3,
                                  focus_elevation = 75e-3,
) for i in range(4)]

for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

# %%
test_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)
test_transducer_set.generate_extrinsics(shape="spherical", extrinsics_kwargs={'r_mean': 100e-3, 'view_std': 0, 'yaw_fraction': 0.5, 'pitch_fraction': 0, 'roll_fraction': 0})
test_transducer_set.plot_transducer_fovs(scale=0.1)
test_transducer_set.plot_transducer_coords(scale=0.1)

# %%
# test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='pressure_field')
test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='transmit_as_receive')

# %%
simprops = simulation.SimProperties(
                grid_size   = (120e-3,30e-3,30e-3),
                voxel_size  = (0.1e-3,0.1e-3,0.1e-3),
                PML_size    = (32,8,8),
                PML_alpha   = 2,
                t_end       = 12e-5,           # [s]
                bona        = 6,               # parameter b/a determining degree of nonlinear acoustic effects
                alpha_coeff = 0.5, 	           # [dB/(MHz^y cm)]
                alpha_power = 1.5,
                )

# %%
test_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/test_experiment_03',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = test_transducer_set,
                 sensor          = test_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 3,
                 additional_keys = ['p_max']
                 )

test_experiment.save()

# %%
test_experiment.plot_ray_path(0)

# %%
test_experiment = experiment.Experiment.load('../experiment_files/test_experiment_03')
test_experiment.run(dry=True)
# Out:
# Number of simulation results (16) is less than the expected number of simulation results (64), are you sure the simulation finished running?
# dry run of simulation
# 100%|██████████| 4/4 [00:00<00:00, 12.07it/s]

# %%
test_experiment.run(repeat=True)
# Out:
# running with 3 workers
#
# preparation for sim    0 completed in            1.51 seconds
#
# preparation for sim   32 completed in            1.60 seconds
#
# preparation for sim    1 completed in            2.04 seconds
#
# preparation for sim   33 completed in            1.99 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                              324 x 96 x 96 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   2347 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.02s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# preparation for sim   34 completed in            1.61 seconds
#
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.09s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                             417MB │
# │ Current device memory in use:                           770MB │
# │ Expected output file size:                               25MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.001s  │      1.171s  │  29/04/24 13:05:53 │
# │     5%   │        0.107s  │      2.011s  │  29/04/24 13:05:54 │
# │    10%   │        0.215s  │      1.920s  │  29/04/24 13:05:53 │
# │    15%   │        0.323s  │      1.818s  │  29/04/24 13:05:54 │
# │    20%   │        0.430s  │      1.714s  │  29/04/24 13:05:54 │
# │    25%   │        0.538s  │      1.608s  │  29/04/24 13:05:54 │
# preparation for sim    2 completed in            2.25 seconds
#
# │    30%   │        0.646s  │      1.501s  │  29/04/24 13:05:54 │
# │    35%   │        0.753s  │      1.395s  │  29/04/24 13:05:54 │
# │    40%   │        0.861s  │      1.288s  │  29/04/24 13:05:54 │
# │    45%   │        0.969s  │      1.181s  │  29/04/24 13:05:54 │
# │    50%   │        1.076s  │      1.074s  │  29/04/24 13:05:54 │
# │    55%   │        1.184s  │      0.967s  │  29/04/24 13:05:53 │
# │    60%   │        1.292s  │      0.859s  │  29/04/24 13:05:53 │
# │    65%   │        1.399s  │      0.751s  │  29/04/24 13:05:54 │
# │    70%   │        1.507s  │      0.644s  │  29/04/24 13:05:54 │
# │    75%   │        1.615s  │      0.536s  │  29/04/24 13:05:54 │
# │    80%   │        1.722s  │      0.429s  │  29/04/24 13:05:54 │
# │    85%   │        1.830s  │      0.322s  │  29/04/24 13:05:54 │
# │    90%   │        1.938s  │      0.214s  │  29/04/24 13:05:54 │
# │    95%   │        2.045s  │      0.106s  │  29/04/24 13:05:54 │
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                           2.16s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                                418MB │
# │ Peak device memory in use:                              770MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                   3.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      0 completed in  4.92 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                              324 x 96 x 96 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   2347 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.02s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.07s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                             417MB │
# │ Current device memory in use:                           770MB │
# │ Expected output file size:                               25MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.001s  │      1.163s  │  29/04/24 13:05:59 │
# │     5%   │        0.107s  │      2.012s  │  29/04/24 13:06:00 │
# │    10%   │        0.214s  │      1.916s  │  29/04/24 13:05:59 │
# │    15%   │        0.322s  │      1.812s  │  29/04/24 13:05:59 │
# │    20%   │        0.429s  │      1.708s  │  29/04/24 13:05:59 │
# │    25%   │        0.536s  │      1.603s  │  29/04/24 13:05:59 │
# │    30%   │        0.644s  │      1.496s  │  29/04/24 13:05:59 │
# │    35%   │        0.751s  │      1.390s  │  29/04/24 13:05:59 │
# │    40%   │        0.858s  │      1.284s  │  29/04/24 13:06:00 │
# │    45%   │        0.966s  │      1.177s  │  29/04/24 13:06:00 │
# │    50%   │        1.073s  │      1.070s  │  29/04/24 13:06:00 │
# │    40%   │        0.877s  │      1.313s  │  29/04/24 13:11:45 │
# │    45%   │        0.995s  │      1.212s  │  29/04/24 13:11:45 │
# │    50%   │        1.114s  │      1.111s  │  29/04/24 13:11:46 │
# │    55%   │        1.232s  │      1.006s  │  29/04/24 13:11:46 │
# │    60%   │        1.346s  │      0.895s  │  29/04/24 13:11:45 │
# │    65%   │        1.458s  │      0.783s  │  29/04/24 13:11:45 │
# │    70%   │        1.570s  │      0.671s  │  29/04/24 13:11:45 │
# │    75%   │        1.682s  │      0.558s  │  29/04/24 13:11:45 │
# │    80%   │        1.793s  │      0.447s  │  29/04/24 13:11:45 │
# │    85%   │        1.904s  │      0.335s  │  29/04/24 13:11:45 │
# │    90%   │        2.018s  │      0.222s  │  29/04/24 13:11:45 │
# │    95%   │        2.134s  │      0.111s  │  29/04/24 13:11:46 │
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                           2.26s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                                419MB │
# │ Peak device memory in use:                              770MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                   3.04s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation     63 completed in  5.00 seconds

# %%
test_experiment.add_results()

# %%
test_reconstruction = reconstruction.DAS(experiment=test_experiment)

# %%
# test_reconstruction.plot_ray_path(0)

# %%
# test_reconstruction.plot_scatter()

# %%
image, signals = test_reconstruction.get_image(dimensions=2, downsample = 1, workers=1)
# Out:
# multiproc time 0.16445398330688477
# 100%|██████████| 4/4 [00:02<00:00,  1.54it/s]

# %%
X = np.linspace(-1, 1, 256)
Y = np.linspace(-1, 1, 256)
X, Y = np.meshgrid(X, Y)

fig, ax = plt.subplots(2,4, figsize=(10,5))
ax[0,0].pcolormesh(X, Y, signals[0], shading='auto', cmap='gray', norm='log')
ax[0,1].pcolormesh(X, Y, signals[1], shading='auto', cmap='gray', norm='log')
ax[0,2].pcolormesh(X, Y, signals[2], shading='auto', cmap='gray', norm='log')
ax[0,3].pcolormesh(X, Y, signals[3], shading='auto', cmap='gray', norm='log')
# ax[1,0].pcolormesh(X, Y, signals[4], shading='auto', cmap='gray', norm='log')
# ax[1,1].pcolormesh(X, Y, signals[5], shading='auto', cmap='gray', norm='log')
# ax[1,2].pcolormesh(X, Y, signals[6], shading='auto', cmap='gray', norm='log')
# ax[1,3].pcolormesh(X, Y, signals[7], shading='auto', cmap='gray', norm='log')

for axd1 in ax:
    for a in axd1:
        a.set_aspect('equal')
        a.set_xticks([])
        a.set_yticks([])

fig, ax = plt.subplots(1,1, figsize=(10,10))
ax.pcolormesh(X, Y, image, shading='auto', cmap='gray', norm='log')
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
fig, ax = plt.subplots(1, 1)
image_rays = np.stack([np.mean(test_experiment.results[i][1], axis=0)[100:] for i in range(len(test_experiment.results))])
ax.pcolor(np.log(image_rays + 2))

# %%
im = test_reconstruction.results[0][2]

# %%
im2 = im.reshape((1232,112,-1))

# %%
plt.imshow(im2)

# %%
im.shape

# %%
plt.imshow(im[:,:,300].T, cmap='bwr')

# %%
for frame in tqdm.tqdm(range(0,im.shape[-1],10)):
    plt.imshow(im[:,:,frame], cmap='bwr')
    plt.colorbar()
    plt.savefig(f'../experiment_files/outputs/frame_{str(frame).zfill(4)}.png', dpi=50)
    plt.close()
