# %%
import sys
sys.path.append('../utils')
sys.path.append('../core')
sys.path.append('../')
import numpy as np
import scipy
import tqdm
import utils
import geometry
from core import *

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import glob

# %%
test_phantom = phantom.Phantom(source_path = None,
            voxel_dims = (0.5e-3,0.5e-3,0.5e-3),
            matrix_dims = (300,300,300),
            baseline = (1500, 1000),
            seed = 5678,)

blood = tissue.Tissue(name='blood', c=1578, rho=1060, sigma=5.3, scale=0.00001, label=1)
myocardium = tissue.Tissue(name='myocardium', c=1561.3, rho=1081, sigma=30, scale=0.0001, label=2)
fat = tissue.Tissue(name='fat', c=1450, rho=920, sigma=10, scale=0.0001, label=3)

pos = 0.7

test_phantom.add_tissue_sphere((pos,-pos,0), 8, blood)
test_phantom.add_tissue_sphere((pos,0,0), 16, blood)
test_phantom.add_tissue_sphere((pos,pos,0), 32, blood)

test_phantom.add_tissue_sphere((-pos,-pos,0), 16, fat)
test_phantom.add_tissue_sphere((-pos,0,0), 32, fat)
test_phantom.add_tissue_sphere((-pos,pos,0), 8, fat)

test_phantom.add_tissue_sphere((0,-pos,0), 32, myocardium)
test_phantom.add_tissue_sphere((0,0,0), 8, myocardium)
test_phantom.add_tissue_sphere((0,pos,0), 16, myocardium)

# %%
plt.imshow(test_phantom.get_complete()[0,:,:,test_phantom.matrix_dims[2]//2])

# %%
transducers = [transducer.Focused(elements = 64, 
                       width = 20e-3,
                       height =  20e-3,
                       sensor_sampling_scheme = 'not_centroid', 
                       sweep = np.pi/2,
                       ray_num = 3, 
                       imaging_ndims = 2,
                       focus_azimuth = 75e-3,
                       focus_elevation = 75e-3,
                       ) for i in range(1)]

for t in transducers:
    t.make_sensor_coords(test_phantom.baseline[0])

# %%
test_transducer_set = transducer_set.TransducerSet(transducers, seed=8888)
test_transducer_set.generate_extrinsics(shape="spherical", extrinsics_kwargs={'r_mean': 100e-3, 'view_std': 0, 'yaw_fraction': 1, 'pitch_fraction': 0, 'roll_fraction': 0})
test_transducer_set.plot_transducer_fovs(scale=0.1)
test_transducer_set.plot_transducer_coords(scale=0.1)

# %%
test_sensor = sensor.Sensor(transducer_set=test_transducer_set, aperture_type='pressure_field')

# %%
simprops = simulation.SimProperties(
                grid_size   = (40e-3,20e-3,20e-3),
                voxel_size  = (0.1e-3,0.1e-3,0.1e-3),
                PML_size    = (32,8,8),
                PML_alpha   = 2,
                t_end       = 12e-5,           # [s]
                bona        = 6,               # parameter b/a determining degree of nonlinear acoustic effects
                alpha_coeff = 0.5, 	           # [dB/(MHz^y cm)]
                alpha_power = 1.5,
                )

# %%
test_experiment = experiment.Experiment(
                 simulation_path = '../experiment_files/test_experiment_02',
                 sim_properties  = simprops,
                 phantom         = test_phantom,
                 transducer_set  = test_transducer_set,
                 sensor          = test_sensor,
                 nodes           = 1,
                 results         = None,
                 indices         = None,
                 workers         = 3,
                 additional_keys = ['p_max']
                 )

test_experiment.save()
# Out:
# ['p_max']

# %%
# test_experiment.plot_ray_path(1)

# %%
test_experiment = experiment.Experiment.load('../experiment_files/test_experiment_02')
test_experiment.run(dry=True)
# Out:
# []
# Number of simulation results (0) is less than the expected number of simulation results (3), are you sure the simulation finished running?
# dry run of simulation
# 100%|██████████| 1/1 [00:00<00:00,  1.48it/s]

# %%
test_experiment.run(repeat=True)
# Out:
# running with 3 workers
#
# preparation for sim    0 completed in            0.58 seconds
# preparation for sim    2 completed in            0.58 seconds
# preparation for sim    1 completed in            1.07 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                            256 x 128 x 128 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   1565 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0
│
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                           2.11s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                                533MB │
# │ Peak device memory in use:                              888MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                   2.61s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      2 completed in  6.91 seconds
# WARNING:root:DeprecationWarning: Attributes will soon be typed when saved and not saved
# ┌───────────────────────────────────────────────────────────────┐
# │                  kspaceFirstOrder-CUDA v1.3                   │
# ├───────────────────────────────────────────────────────────────┤
# │ Reading simulation configuration:                        Done │
# │ Selected GPU device id:                                     0 │
# │ GPU device name:               NVIDIA RTX 6000 Ada Generation │
# │ Number of CPU threads:                                     32 │
# │ Processor name: AMD Ryzen Threadripper PRO 5955WX 16-Cores    │
# ├───────────────────────────────────────────────────────────────┤
# │                      Simulation details                       │
# ├───────────────────────────────────────────────────────────────┤
# │ Domain dimensions:                            256 x 128 x 128 │
# │ Medium type:                                               3D │
# │ Simulation time steps:                                   1565 │
# ├───────────────────────────────────────────────────────────────┤
# │                        Initialization                         │
# ├───────────────────────────────────────────────────────────────┤
# │ Memory allocation:                                       Done │
# │ Data loading:                                            Done │
# │ Elapsed time:                                           0.03s │
# ├───────────────────────────────────────────────────────────────┤
# │ FFT plans creation:                                      Done │
# │ Pre-processing phase:                                    Done │
# │ Elapsed time:                                           0.01s │
# ├───────────────────────────────────────────────────────────────┤
# │                    Computational resources                    │
# ├───────────────────────────────────────────────────────────────┤
# │ Current host memory in use:                             532MB │
# │ Current device memory in use:                           888MB │
# │ Expected output file size:                              128MB │
# ├───────────────────────────────────────────────────────────────┤
# │                          Simulation                           │
# ├──────────┬────────────────┬──────────────┬────────────────────┤
# │ Progress │  Elapsed time  │  Time to go  │  Est. finish time  │
# ├──────────┼────────────────┼──────────────┼────────────────────┤
# │     0%   │        0.001s  │      1.127s  │  26/04/24 15:02:04 │
# │     5%   │        0.107s  │      1.982s  │  26/04/24 15:02:04 │
# │    10%   │        0.212s  │      1.886s  │  26/04/24 15:02:04 │
# │    15%   │        0.316s  │      1.780s  │  26/04/24 15:02:04 │
# │    20%   │        0.421s  │      1.672s  │  26/04/24 15:02:04 │
# │    25%   │        0.526s  │      1.567s  │  26/04/24 15:02:04 │
# │    30%   │        0.629s  │      1.462s  │  26/04/24 15:02:04 │
# │    35%   │        0.733s  │      1.357s  │  26/04/24 15:02:05 │
# │    40%   │        0.839s  │      1.251s  │  26/04/24 15:02:05 │
# │    45%   │        0.943s  │      1.147s  │  26/04/24 15:02:05 │
# │    50%   │        1.047s  │      1.043s  │  26/04/24 15:02:05 │
# │    55%   │        1.151s  │      0.938s  │  26/04/24 15:02:04 │
# │    60%   │        1.256s  │      0.833s  │  26/04/24 15:02:04 │
# │    65%   │        1.360s  │      0.729s  │  26/04/24 15:02:04 │
# │    70%   │        1.464s  │      0.624s  │  26/04/24 15:02:04 │
# │    75%   │        1.568s  │      0.520s  │  26/04/24 15:02:04 │
# │    80%   │        1.673s  │      0.415s  │  26/04/24 15:02:04 │
# │    85%   │        1.777s  │      0.311s  │  26/04/24 15:02:05 │
# │    90%   │        1.881s  │      0.207s  │  26/04/24 15:02:05 │
# │    95%   │        1.985s  │      0.103s  │  26/04/24 15:02:05 │
# ├──────────┴────────────────┴──────────────┴────────────────────┤
# │ Elapsed time:                                           2.11s │
# ├───────────────────────────────────────────────────────────────┤
# │ Sampled data post-processing:                            Done │
# │ Elapsed time:                                           0.00s │
# ├───────────────────────────────────────────────────────────────┤
# │                            Summary                            │
# ├───────────────────────────────────────────────────────────────┤
# │ Peak host memory in use:                                534MB │
# │ Peak device memory in use:                              888MB │
# ├───────────────────────────────────────────────────────────────┤
# │ Total execution time:                                   2.61s │
# ├───────────────────────────────────────────────────────────────┤
# │                       End of computation                      │
# └───────────────────────────────────────────────────────────────┘
# simulation      1 completed in  6.83 seconds

# %%
test_experiment.add_results()

# %%
test_reconstruction = reconstruction.DAS(experiment=test_experiment)

# %%
test_reconstruction.plot_ray_path(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 test_reconstruction.plot_ray_path(0)
#
# File ~/repos/MUSiK/debugging/../core/reconstruction.py:74, in DAS.plot_ray_path(self, index, ax, save, save_path, cmap)
#      72 self.experiment.plot_ray_path(index, ax=ax)
#      73 centerline = self.sim_properties.grid_size[1] // 2 - self.sim_properties.PML_size[1]
# ---> 74 ax[0].plot(self.experiment.results[index][0] / self.experiment.phantom.voxel_dims[0] * 1540 / 2, self.experiment.results[index][1].T / 20 + centerline, linewidth=0.1, color='cyan', alpha=0.5)
#      75 ax[0].set_ylim(0, centerline * 2)
#      76 ax[1].plot(self.experiment.results[index][0] / self.experiment.phantom.voxel_dims[0] * 1540 / 2, self.experiment.results[index][1].T / 20 + centerline, linewidth=0.1, color='cyan', alpha=0.5)
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1670, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
# -> 1670     self.add_line(line)
#    1671 if scalex:
#    1672     self._request_autoscale_view("x")
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/axes/_base.py:2333, in _AxesBase.add_line(self, line)
#    2330 if line.get_clip_path() is None:
#    2331     line.set_clip_path(self.patch)
# -> 2333 self._update_line_limits(line)
#    2334 if not line.get_label():
#    2335     line.set_label(f'_child{len(self._children)}')
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/axes/_base.py:2387, in _AxesBase._update_line_limits(self, line)
#    2384 if not data_path.vertices.size:
#    2385     return
# -> 2387 updatex, updatey = line_trf.contains_branch_seperately(self.transData)
#    2388 if self.name != "rectilinear":
#    2389     # This block is mostly intended to handle axvline in polar plots,
#    2390     # for which updatey would otherwise be True.
#    2391     if updatex and line_trf == self.get_yaxis_transform():
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:1411, in Transform.contains_branch_seperately(self, other_transform)
#    1407     raise ValueError('contains_branch_seperately only supports '
#    1408                      'transforms with 2 output dimensions')
#    1409 # for a non-blended transform each separate dimension is the same, so
#    1410 # just return the appropriate shape.
# -> 1411 return [self.contains_branch(other_transform)] * 2
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:1390, in Transform.contains_branch(self, other)
#    1387     return False
#    1389 # check that a subtree is equal to other (starting from self)
# -> 1390 for _, sub_tree in self._iter_break_from_left_to_right():
#    1391     if sub_tree == other:
#    1392         return True
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:2405, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2403 def _iter_break_from_left_to_right(self):
#    2404     for left, right in self._a._iter_break_from_left_to_right():
# -> 2405         yield left, right + self._b
#    2406     for left, right in self._b._iter_break_from_left_to_right():
#    2407         yield self._a + left, right
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:1342, in Transform.__add__(self, other)
#    1335 def __add__(self, other):
#    1336     """
#    1337     Compose two transforms together so that *self* is followed by *other*.
#    1338
#    1339     ``A + B`` returns a transform ``C`` so that
#    1340     ``C.transform(x) == B.transform(A.transform(x))``.
#    1341     """
# -> 1342     return (composite_transform_factory(self, other)
#    1343             if isinstance(other, Transform) else
#    1344             NotImplemented)
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:2532, in composite_transform_factory(a, b)
#    2530 elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2531     return CompositeAffine2D(a, b)
# -> 2532 return CompositeGenericTransform(a, b)
#
# File ~/miniconda3/envs/musik/lib/python3.9/site-packages/matplotlib/transforms.py:2367, in CompositeGenericTransform.__init__(self, a, b, **kwargs)
#    2364 self.input_dims = a.input_dims
#    2365 self.output_dims = b.output_dims
# -> 2367 super().__init__(**kwargs)
#    2368 self._a = a
#    2369 self._b = b
#
# KeyboardInterrupt:

# %%
test_reconstruction.plot_scatter()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test_reconstruction.plot_scatter()
#
# File ~/repos/MUSiK/debugging/../core/reconstruction.py:162, in DAS.plot_scatter(self, scale, workers)
#     152 def plot_scatter(self, scale=5000, workers=1):
#     154     colorme = lambda x: (     [1,0,0] if x % 7 == 0
#     155                          else [0,1,0] if x % 7 == 1
#     156                          else [0,0,1] if x % 7 == 2
#    (...)
#     159                          else [0,1,1] if x % 7 == 5
#     160                          else [1,1,1])
# --> 162     times, coords, processed = self.preprocess_data(workers=workers)
#     163     coords = np.stack(coords, axis=0)
#     164     processed = np.stack(processed, axis=0)
#
# File ~/repos/MUSiK/debugging/../core/reconstruction.py:127, in DAS.preprocess_data(self, workers)
#     125 if index > running_index_list[transducer_count] - 1:
#     126     transducer_count += 1
# --> 127     transducer, transducer_transform = self.transducer_set[transducer_count]
#     128 transform = transducer_transform * transducer.ray_transforms[index - running_index_list[transducer_count]]
#     130 indices.append(index)
#
# File ~/repos/MUSiK/debugging/../core/transducer_set.py:31, in TransducerSet.__getitem__(self, index)
#      30 def __getitem__(self, index):
# ---> 31     return self.transducers[index], self.poses[index]
#
# IndexError: list index out of range

# %%
image, signals = test_reconstruction.get_image(dimensions=2, downsample = 1, workers=1)
# Out:
# multiproc time 0.005710124969482422
# 100%|██████████| 1/1 [00:00<00:00,  5.60it/s]

# %%
X = np.linspace(-1, 1, 256)
Y = np.linspace(-1, 1, 256)
X, Y = np.meshgrid(X, Y)

fig, ax = plt.subplots(2,4, figsize=(10,5))
ax[0,0].pcolormesh(X, Y, signals[0], shading='auto', cmap='gray', norm='log')
ax[0,1].pcolormesh(X, Y, signals[1], shading='auto', cmap='gray', norm='log')
ax[0,2].pcolormesh(X, Y, signals[2], shading='auto', cmap='gray', norm='log')
ax[0,3].pcolormesh(X, Y, signals[3], shading='auto', cmap='gray', norm='log')
ax[1,0].pcolormesh(X, Y, signals[4], shading='auto', cmap='gray', norm='log')
ax[1,1].pcolormesh(X, Y, signals[5], shading='auto', cmap='gray', norm='log')
ax[1,2].pcolormesh(X, Y, signals[6], shading='auto', cmap='gray', norm='log')
ax[1,3].pcolormesh(X, Y, signals[7], shading='auto', cmap='gray', norm='log')

for axd1 in ax:
    for a in axd1:
        a.set_aspect('equal')
        a.set_xticks([])
        a.set_yticks([])

fig, ax = plt.subplots(1,1, figsize=(10,10))
ax.pcolormesh(X, Y, image, shading='auto', cmap='gray', norm='log')
ax.set_aspect('equal')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 7
#       5 fig, ax = plt.subplots(2,4, figsize=(10,5))
#       6 ax[0,0].pcolormesh(X, Y, signals[0], shading='auto', cmap='gray', norm='log')
# ----> 7 ax[0,1].pcolormesh(X, Y, signals[1], shading='auto', cmap='gray', norm='log')
#       8 ax[0,2].pcolormesh(X, Y, signals[2], shading='auto', cmap='gray', norm='log')
#       9 ax[0,3].pcolormesh(X, Y, signals[3], shading='auto', cmap='gray', norm='log')
#
# IndexError: list index out of range

# %%
X = np.linspace(-1, 1, 256)
Y = np.linspace(-1, 1, 256)
X, Y = np.meshgrid(X, Y)

fig, ax = plt.subplots(2,4, figsize=(10,5))
ax[0,0].pcolormesh(X, Y, signals[0], shading='auto', cmap='gray', norm='log')
ax[0,1].pcolormesh(X, Y, signals[1], shading='auto', cmap='gray', norm='log')
ax[0,2].pcolormesh(X, Y, signals[2], shading='auto', cmap='gray', norm='log')
ax[0,3].pcolormesh(X, Y, signals[3], shading='auto', cmap='gray', norm='log')
ax[1,0].pcolormesh(X, Y, signals[4], shading='auto', cmap='gray', norm='log')
ax[1,1].pcolormesh(X, Y, signals[5], shading='auto', cmap='gray', norm='log')
ax[1,2].pcolormesh(X, Y, signals[6], shading='auto', cmap='gray', norm='log')
ax[1,3].pcolormesh(X, Y, signals[7], shading='auto', cmap='gray', norm='log')

fig, ax = plt.subplots(1,1, figsize=(10,10))
ax.pcolormesh(X, Y, image, shading='auto', cmap='gray', norm='log')

# %%
plt.imshow(image, vmax=10000)

# %%
fig, ax = plt.subplots(1, 1)
image_rays = np.stack([np.mean(test_experiment.results[i][1], axis=0)[100:] for i in range(len(test_experiment.results))])
ax.pcolor(np.log(image_rays + 2))
# Out:
# /tmp/ipykernel_602626/4135272851.py:3: RuntimeWarning: invalid value encountered in log
#   ax.pcolor(np.log(image_rays + 2))

# %%
192*112
# Out:
# 21504

# %%
im = test_reconstruction.results[0][1].reshape((112,192,-1))

# %%
for frame in tqdm.tqdm(range(0,im.shape[-1],10)):
    plt.imshow(im[:,:,frame], cmap='bwr')
    plt.colorbar()
    plt.savefig(f'../experiment_files/outputs/frame_{str(frame).zfill(4)}.png', dpi=50)
    plt.close()
# Out:
# 100%|██████████| 157/157 [00:12<00:00, 12.16it/s]
